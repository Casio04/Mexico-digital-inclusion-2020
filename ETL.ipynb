# %% [markdown]
# # ETL PROCESSING

# %%
# Import dependencies
import pandas as pd
import re

# %% [markdown]
# ## Extract

# %%
# Read data
data = pd.read_csv("data/Censo_2020.csv")
# Out:
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#    ENTIDAD         NOM_ENT  MUN                             NOM_MUN   LOC  \
# 0        0  Total nacional    0                      Total nacional     0
# 1        0  Total nacional    0                      Total nacional  9998
# 2        0  Total nacional    0                      Total nacional  9999
# 3        1  Aguascalientes    0  Total de la entidad Aguascalientes     0
# 4        1  Aguascalientes    0  Total de la entidad Aguascalientes  9998
#
#                         NOM_LOC LONGITUD LATITUD ALTITUD     POBTOT  ...  \
# 0                Total nacional      NaN     NaN     NaN  126014024  ...
# 1   Localidades de una vivienda      NaN     NaN     NaN     250354  ...
# 2  Localidades de dos viviendas      NaN     NaN     NaN     147125  ...
# 3           Total de la Entidad      NaN     NaN     NaN    1425607  ...
# 4   Localidades de una vivienda      NaN     NaN     NaN       3697  ...
#
#     VPH_CEL VPH_INTER  VPH_STVP VPH_SPMVPI  VPH_CVJ VPH_SINRTV VPH_SINLTC  \
# 0  30775898  18307193  15211306    6616141  4047100    1788552    3170894
# 1     47005      8385     18981       1732     1113      12775      14143
# 2     25581      5027     11306        971      708       8247      10065
# 3    359895    236003    174089      98724    70126       6021      15323
# 4       732       205       212         48       41         39         62
#
#   VPH_SINCINT VPH_SINTIC TAMLOC
# 0    15108204     852871      *
# 1       51293       7154      *
# 2       29741       5283      *
# 3      128996       1711      *
# 4         530         20      *
#
# [5 rows x 231 columns]

# %%
data.describe()
# Out:
#              ENTIDAD            MUN            LOC        POBTOT  \
# count  195662.000000  195662.000000  195662.000000  1.956620e+05
# mean       16.806743      59.699400     623.572221  2.582252e+03
# std         8.940159      81.370934    1502.609425  2.931486e+05
# min         0.000000       0.000000       0.000000  1.000000e+00
# 25%         8.000000      12.000000      45.000000  4.000000e+00
# 50%        16.000000      33.000000     162.000000  1.600000e+01
# 75%        25.000000      73.000000     531.000000  1.470000e+02
# max        32.000000     570.000000    9999.000000  1.260140e+08
#
#              VIVTOT       TVIVHAB
# count  1.956620e+05  1.956620e+05
# mean   9.000329e+02  7.218171e+02
# std    1.019782e+05  8.195072e+04
# min    0.000000e+00  0.000000e+00
# 25%    2.000000e+00  1.000000e+00
# 50%    7.000000e+00  4.000000e+00
# 75%    5.400000e+01  3.800000e+01
# max    4.390344e+07  3.523346e+07

# %%
data.shape
# Out:
# (195662, 231)

# %% [markdown]
# ## Transform

# %%
# First, we remove all the blank values from rows that sum up total, since they don't have any latitude or longitude we can use
data = data.dropna()

# %%
# Then, we create a function to change the coordinates to the correct type
def dms2dd(s):
    # example: s = """0°51'56.29"S"""
    degrees, minutes, seconds, direction = re.split('[°\'"]+', s)
    dd = float(degrees) + float(minutes)/60 + float(seconds)/(60*60);
    if direction in ('S','W'):
        dd*= -1
    return dd

# %%
# We use the function to change both latitude and longitude columns
data['LATITUD'] = data['LATITUD'].apply(dms2dd)
data['LONGITUD'] = data['LONGITUD'].apply(dms2dd)*-1

# %%
# Here we print all the columns to see which ones will be left on the final Dataframe
for x in data:
    print(x)
# Out:
# ENTIDAD
# NOM_ENT
# MUN
# NOM_MUN
# LOC
# NOM_LOC
# LONGITUD
# LATITUD
# ALTITUD
# POBTOT
# POBFEM
# POBMAS
# P_0A2
# P_0A2_F
# P_0A2_M
# P_3YMAS
# P_3YMAS_F
# P_3YMAS_M
# P_5YMAS
# P_5YMAS_F
# P_5YMAS_M
# P_12YMAS
# P_12YMAS_F
# P_12YMAS_M
# P_15YMAS
# P_15YMAS_F
# P_15YMAS_M
# P_18YMAS
# P_18YMAS_F
# P_18YMAS_M
# P_3A5
# P_3A5_F
# P_3A5_M
# P_6A11
# P_6A11_F
# P_6A11_M
# P_8A14
# P_8A14_F
# P_8A14_M
# P_12A14
# P_12A14_F
# P_12A14_M
# P_15A17
# P_15A17_F
# P_15A17_M
# P_18A24
# P_18A24_F
# P_18A24_M
# P_15A49_F
# P_60YMAS
# P_60YMAS_F
# P_60YMAS_M
# REL_H_M
# POB0_14
# POB15_64
# POB65_MAS
# PROM_HNV
# PNACENT
# PNACENT_F
# PNACENT_M
# PNACOE
# PNACOE_F
# PNACOE_M
# PRES2015
# PRES2015_F
# PRES2015_M
# PRESOE15
# PRESOE15_F
# PRESOE15_M
# P3YM_HLI
# P3YM_HLI_F
# P3YM_HLI_M
# P3HLINHE
# P3HLINHE_F
# P3HLINHE_M
# P3HLI_HE
# P3HLI_HE_F
# P3HLI_HE_M
# P5_HLI
# P5_HLI_NHE
# P5_HLI_HE
# PHOG_IND
# POB_AFRO
# POB_AFRO_F
# POB_AFRO_M
# PCON_DISC
# PCDISC_MOT
# PCDISC_VIS
# PCDISC_LENG
# PCDISC_AUD
# PCDISC_MOT2
# PCDISC_MEN
# PCON_LIMI
# PCLIM_CSB
# PCLIM_VIS
# PCLIM_HACO
# PCLIM_OAUD
# PCLIM_MOT2
# PCLIM_RE_CO
# PCLIM_PMEN
# PSIND_LIM
# P3A5_NOA
# P3A5_NOA_F
# P3A5_NOA_M
# P6A11_NOA
# P6A11_NOAF
# P6A11_NOAM
# P12A14NOA
# P12A14NOAF
# P12A14NOAM
# P15A17A
# P15A17A_F
# P15A17A_M
# P18A24A
# P18A24A_F
# P18A24A_M
# P8A14AN
# P8A14AN_F
# P8A14AN_M
# P15YM_AN
# P15YM_AN_F
# P15YM_AN_M
# P15YM_SE
# P15YM_SE_F
# P15YM_SE_M
# P15PRI_IN
# P15PRI_INF
# P15PRI_INM
# P15PRI_CO
# P15PRI_COF
# P15PRI_COM
# P15SEC_IN
# P15SEC_INF
# P15SEC_INM
# P15SEC_CO
# P15SEC_COF
# P15SEC_COM
# P18YM_PB
# P18YM_PB_F
# P18YM_PB_M
# GRAPROES
# GRAPROES_F
# GRAPROES_M
# PEA
# PEA_F
# PEA_M
# PE_INAC
# PE_INAC_F
# PE_INAC_M
# POCUPADA
# POCUPADA_F
# POCUPADA_M
# PDESOCUP
# PDESOCUP_F
# PDESOCUP_M
# PSINDER
# PDER_SS
# PDER_IMSS
# PDER_ISTE
# PDER_ISTEE
# PAFIL_PDOM
# PDER_SEGP
# PDER_IMSSB
# PAFIL_IPRIV
# PAFIL_OTRAI
# P12YM_SOLT
# P12YM_CASA
# P12YM_SEPA
# PCATOLICA
# PRO_CRIEVA
# POTRAS_REL
# PSIN_RELIG
# TOTHOG
# HOGJEF_F
# HOGJEF_M
# POBHOG
# PHOGJEF_F
# PHOGJEF_M
# VIVTOT
# TVIVHAB
# TVIVPAR
# VIVPAR_HAB
# TVIVPARHAB
# VIVPAR_DES
# VIVPAR_UT
# OCUPVIVPAR
# PROM_OCUP
# PRO_OCUP_C
# VPH_PISODT
# VPH_PISOTI
# VPH_1DOR
# VPH_2YMASD
# VPH_1CUART
# VPH_2CUART
# VPH_3YMASC
# VPH_C_ELEC
# VPH_S_ELEC
# VPH_AGUADV
# VPH_AEASP
# VPH_AGUAFV
# VPH_TINACO
# VPH_CISTER
# VPH_EXCSA
# VPH_LETR
# VPH_DRENAJ
# VPH_NODREN
# VPH_C_SERV
# VPH_NDEAED
# VPH_DSADMA
# VPH_NDACMM
# VPH_SNBIEN
# VPH_REFRI
# VPH_LAVAD
# VPH_HMICRO
# VPH_AUTOM
# VPH_MOTO
# VPH_BICI
# VPH_RADIO
# VPH_TV
# VPH_PC
# VPH_TELEF
# VPH_CEL
# VPH_INTER
# VPH_STVP
# VPH_SPMVPI
# VPH_CVJ
# VPH_SINRTV
# VPH_SINLTC
# VPH_SINCINT
# VPH_SINTIC
# TAMLOC

# %%
# First, we create a dataframe only with the columns we need
final_df = data[["ENTIDAD","NOM_ENT", "MUN", "NOM_MUN","NOM_LOC","LONGITUD","LATITUD","POBTOT","POBFEM","POBMAS","PEA","TVIVPARHAB","VPH_RADIO","VPH_TV","VPH_PC","VPH_TELEF","VPH_CEL","VPH_INTER","VPH_STVP","VPH_SPMVPI","VPH_CVJ"]]
# Then, we replace the asterisk values with zeros and "N/D" values we found when exploring data
final_df = final_df.replace("*",0)
final_df = final_df.replace("N/D",0)

# %%
final_df
# Out:
#         ENTIDAD         NOM_ENT  MUN                NOM_MUN  \
# 7             1  Aguascalientes    1         Aguascalientes
# 8             1  Aguascalientes    1         Aguascalientes
# 9             1  Aguascalientes    1         Aguascalientes
# 10            1  Aguascalientes    1         Aguascalientes
# 11            1  Aguascalientes    1         Aguascalientes
# ...         ...             ...  ...                    ...
# 195656       32       Zacatecas   58  Santa María de la Paz
# 195657       32       Zacatecas   58  Santa María de la Paz
# 195658       32       Zacatecas   58  Santa María de la Paz
# 195659       32       Zacatecas   58  Santa María de la Paz
# 195660       32       Zacatecas   58  Santa María de la Paz
#
#                                  NOM_LOC    LONGITUD    LATITUD  POBTOT  \
# 7                         Aguascalientes -102.296047  21.879823  863893
# 8                         Granja Adelita -102.373531  21.871875       5
# 9                              Agua Azul -102.357122  21.883756      41
# 10                Los Arbolitos [Rancho] -102.357295  21.780181       8
# 11      Ardillas de Abajo (Las Ardillas) -102.191921  21.945068       1
# ...                                  ...         ...        ...     ...
# 195656   Los Trigos (Mesa de los Trigos) -103.241053  21.497599      89
# 195657                       Mesa Grande -103.414701  21.553438     165
# 195658                        San Isidro -103.337268  21.486425       1
# 195659             San Miguel Tepetitlán -103.335932  21.504213      97
# 195660                        San Rafael -103.372259  21.527595       3
#
#         POBFEM  POBMAS  ... TVIVPARHAB VPH_RADIO  VPH_TV  VPH_PC VPH_TELEF  \
# 7       444725  419168  ...     246116    204535  237274  130384    112002
# 8            0       0  ...          0         0       0       0         0
# 9           17      24  ...         12        11      11       5         2
# 10           0       0  ...          0         0       0       0         0
# 11           0       0  ...          0         0       0       0         0
# ...        ...     ...  ...        ...       ...     ...     ...       ...
# 195656      43      46  ...         23        13      18       2         0
# 195657      88      77  ...         49        29      44       6        29
# 195658       0       0  ...          0         0       0       0         0
# 195659      50      47  ...         31        20      26       4         1
# 195660       0       0  ...          0         0       0       0         0
#
#        VPH_CEL VPH_INTER VPH_STVP VPH_SPMVPI VPH_CVJ
# 7       232793    169675   123670      77719   53589
# 8            0         0        0          0       0
# 9           11         4        5          2       1
# 10           0         0        0          0       0
# 11           0         0        0          0       0
# ...        ...       ...      ...        ...     ...
# 195656      19         1        5          0       0
# 195657      24         9       13          0       0
# 195658       0         0        0          0       0
# 195659      21        12       21          1       1
# 195660       0         0        0          0       0
#
# [189222 rows x 21 columns]

# %%
# We realized the columns were "object" type because of the asterisk and N/D values we removed before
final_df.dtypes
# Out:
# ENTIDAD         int64
# NOM_ENT        object
# MUN             int64
# NOM_MUN        object
# NOM_LOC        object
# LONGITUD      float64
# LATITUD       float64
# POBTOT          int64
# POBFEM         object
# POBMAS         object
# PEA            object
# TVIVPARHAB     object
# VPH_RADIO      object
# VPH_TV         object
# VPH_PC         object
# VPH_TELEF      object
# VPH_CEL        object
# VPH_INTER      object
# VPH_STVP       object
# VPH_SPMVPI     object
# VPH_CVJ        object
# dtype: object

# %%
# So here we convert the columns to integer type
final_df[final_df.columns[7:].to_list()] = final_df[final_df.columns[7:].to_list()].astype(int)

# %%
final_df.dtypes
# Out:
# ENTIDAD         int64
# NOM_ENT        object
# MUN             int64
# NOM_MUN        object
# NOM_LOC        object
# LONGITUD      float64
# LATITUD       float64
# POBTOT          int32
# POBFEM          int32
# POBMAS          int32
# PEA             int32
# TVIVPARHAB      int32
# VPH_RADIO       int32
# VPH_TV          int32
# VPH_PC          int32
# VPH_TELEF       int32
# VPH_CEL         int32
# VPH_INTER       int32
# VPH_STVP        int32
# VPH_SPMVPI      int32
# VPH_CVJ         int32
# dtype: object

# %%
#Rename columns
final_df = final_df.rename(
    columns={'NOM_ENT':'NOMBRE ENTIDAD',
            'MUN':'MUNICIPIO',
            'NOM_MUN':'NOMBRE MUNICIPIO',
            'NOM_LOC':'NOMBRE LOCALIDAD',
            })

# %%
# Removing latitude and longitude from dataframe and grouping by municipality so we can send it to database
final_df = final_df.groupby(['ENTIDAD',"NOM_ENT","MUN","NOM_MUN"])[final_df.columns[7:].to_list()].apply(lambda x : x.astype(int).sum()).reset_index()

# %%
final_df.head()
# Out:
#    ENTIDAD         NOM_ENT  MUN         NOM_MUN  POBTOT  POBFEM  POBMAS  \
# 0        1  Aguascalientes    1  Aguascalientes  948990  486138  460305
# 1        1  Aguascalientes    2        Asientos   51536   26097   25079
# 2        1  Aguascalientes    3        Calvillo   58250   29584   28430
# 3        1  Aguascalientes    4           Cosío   17000    8626    8187
# 4        1  Aguascalientes    5     Jesús María  129929   65492   63978
#
#       PEA  TVIVPARHAB  VPH_RADIO  VPH_TV  VPH_PC  VPH_TELEF  VPH_CEL  \
# 0  485108      266427     221026  256747  136845     116612   251390
# 1   21269       12442       8821   11707    2794       1685    10592
# 2   25854       15471      10658   14566    3994       4715    13602
# 3    6919        3887       2711    3629     996        549     3380
# 4   65608       33101      27184   31811   15659      12479    31302
#
#    VPH_INTER  VPH_STVP  VPH_SPMVPI  VPH_CVJ
# 0     178518    130206       80923    56106
# 1       4494      3848         590      551
# 2       6537      4736        1380     1350
# 3       1725      1650         221      190
# 4      19879     13441        9283     6570

# %%
final_df.to_csv("data/Censo.csv", index = False)

# %% [markdown]
# ## Load

# %%
import pandas as pd
import json
import pymongo

# %%
data = pd.read_csv("data/Censo.csv")

# %%
#data2 = data.groupby(['ENTIDAD','NOM_ENT']).agg(list)
#data2 = data.pivot_table(columns=['ENTIDAD','NOM_ENT'],index=['MUN','NOM_MUN'], values=columnas[4:],aggfunc=sum)
#data = data.pivot_table(index=['ENTIDAD','NOM_ENT','NOM_MUN'], aggfunc=sum)

# %%
#data = data2.reset_index(level='NOM_MUN')

# %%
columnas = data.columns.to_list()

# %%
resultado_json = (
    data
    .sort_values(by="ENTIDAD")
    .reset_index()
    .loc[:,data.columns.to_list()]
    .to_json(orient="records")
)

# %%
type(resultado_json)
# Out:
# str

# %%
resultado_json
# Out:
# '[{"ENTIDAD":1,"NOM_ENT":"Aguascalientes","MUN":1,"NOM_MUN":"Aguascalientes","POBTOT":948990,"POBFEM":486138,"POBMAS":460305,"PEA":485108,"TVIVPARHAB":266427,"VPH_RADIO":221026,"VPH_TV":256747,"VPH_PC":136845,"VPH_TELEF":116612,"VPH_CEL":251390,"VPH_INTER":178518,"VPH_STVP":130206,"VPH_SPMVPI":80923,"VPH_CVJ":56106},{"ENTIDAD":1,"NOM_ENT":"Aguascalientes","MUN":2,"NOM_MUN":"Asientos","POBTOT":51536,"POBFEM":26097,"POBMAS":25079,"PEA":21269,"TVIVPARHAB":12442,"VPH_RADIO":8821,"VPH_TV":11707,"VPH_PC":2794,"VPH_TELEF":1685,"VPH_CEL":10592,"VPH_INTER":4494,"VPH_STVP":3848,"VPH_SPMVPI":590,"VPH_CVJ":551},{"ENTIDAD":1,"NOM_ENT":"Aguascalientes","MUN":3,"NOM_MUN":"Calvillo","POBTOT":58250,"POBFEM":29584,"POBMAS":28430,"PEA":25854,"TVIVPARHAB":15471,"VPH_RADIO":10658,"VPH_TV":14566,"VPH_PC":3994,"VPH_TELEF":4715,"VPH_CEL":13602,"VPH_INTER":6537,"VPH_STVP":4736,"VPH_SPMVPI":1380,"VPH_CVJ":1350},{"ENTIDAD":1,"NOM_ENT":"Aguascalientes","MUN":4,"NOM_MUN":"Cos\\u00edo","POBTOT":17000,"POBFEM":8626,"POBMAS":8187,"PEA":6919,"TVIVPARHAB":3887,"VPH_RADIO":2711,"VPH_TV":3629,"VPH_PC":996,"VPH_TELEF":549,"VPH_CEL":3380,"VPH_INTER":1725,"VPH_STVP":1650,"VPH_SPMVPI":221,"VPH_CVJ":190},{"ENTIDAD":1,"NOM_ENT":"Aguascalientes","MUN":5,"NOM_MUN":"Jes\\u00fas Mar\\u00eda","POBTOT":129929,"POBFEM":65492,"POBMAS":63978,"PEA":65608,"TVIVPARHAB":33101,"VPH_RADIO":27184,"VPH_TV":31811,"VPH_PC":15659,"VPH_TELEF":12479,"VPH_CEL":31302,"VPH_INTER":19879,"VPH_STVP":13441,"VPH_SPMVPI":9283,"VPH_CVJ":6570},{"ENTIDAD":1,"NOM_ENT":"Aguascalientes","MUN":6,"NOM_MUN":"Pabell\\u00f3n de Arteaga","POBTOT":47646,"POBFEM":24000,"POBMAS":23072,"PEA":21829,"TVIVPARHAB":11311,"VPH_RADIO":8684,"VPH_TV":10863,"VPH_PC":4414,"VPH_TELEF":3585,"VPH_CEL":10213,"VPH_INTER":6166,"VPH_STVP":4677,"VPH_SPMVPI":1917,"VPH_CVJ":1340},{"ENTIDAD":1,"NOM_ENT":"Aguascalientes","MUN":7,"NOM_MUN":"Rinc\\u00f3n de Romos","POBTOT":57369,"POBFEM":28845,"POBMAS":27637,"PEA":26198,"TVIVPARHAB":13356,"VPH_RADIO":9862,"VPH_TV":12590,"VPH_PC":4413,"VPH_TELEF":3220,"VPH_CEL":11976,"VPH_INTER":6233,"VPH_STVP":4491,"VPH_SPMVPI":1555,"VPH_CVJ":1347},{"ENTIDAD":1,"NOM_ENT":"Aguascalientes","MUN":8,"NOM_MUN":"San Jos\\u00e9 de Gracia","POBTOT":9552,"POBFEM":4995,"POBMAS":4506,"PEA":3811,"TVIVPARHAB":2367,"VPH_RADIO":1642,"VPH_TV":2148,"VPH_PC":574,"VPH_TELEF":472,"VPH_CEL":2088,"VPH_INTER":728,"VPH_STVP":1275,"VPH_SPMVPI":161,"VPH_CVJ":113},{"ENTIDAD":1,"NOM_ENT":"Aguascalientes","MUN":9,"NOM_MUN":"Tepezal\\u00e1","POBTOT":22485,"POBFEM":11244,"POBMAS":10961,"PEA":9055,"TVIVPARHAB":5347,"VPH_RADIO":3882,"VPH_TV":5034,"VPH_PC":1160,"VPH_TELEF":589,"VPH_CEL":4542,"VPH_INTER":2038,"VPH_STVP":1305,"VPH_SPMVPI":256,"VPH_CVJ":235},{"ENTIDAD":1,"NOM_ENT":"Aguascalientes","MUN":10,"NOM_MUN":"El Llano","POBTOT":20849,"POBFEM":10227,"POBMAS":9769,"PEA":8087,"TVIVPARHAB":5103,"VPH_RADIO":3561,"VPH_TV":4823,"VPH_PC":1026,"VPH_TELEF":449,"VPH_CEL":4376,"VPH_INTER":1306,"VPH_STVP":981,"VPH_SPMVPI":242,"VPH_CVJ":209},{"ENTIDAD":1,"NOM_ENT":"Aguascalientes","MUN":11,"NOM_MUN":"San Francisco de los Romo","POBTOT":61997,"POBFEM":31153,"POBMAS":30560,"PEA":29363,"TVIVPARHAB":16307,"VPH_RADIO":12916,"VPH_TV":15343,"VPH_PC":4993,"VPH_TELEF":3383,"VPH_CEL":15230,"VPH_INTER":8028,"VPH_STVP":7111,"VPH_SPMVPI":2113,"VPH_CVJ":2036},{"ENTIDAD":2,"NOM_ENT":"Baja California","MUN":6,"NOM_MUN":"San Quint\\u00edn","POBTOT":117553,"POBFEM":57262,"POBMAS":59045,"PEA":58438,"TVIVPARHAB":32304,"VPH_RADIO":14603,"VPH_TV":23978,"VPH_PC":8050,"VPH_TELEF":4901,"VPH_CEL":29949,"VPH_INTER":11557,"VPH_STVP":16872,"VPH_SPMVPI":3269,"VPH_CVJ":1799},{"ENTIDAD":2,"NOM_ENT":"Baja California","MUN":5,"NOM_MUN":"Playas de Rosarito","POBTOT":126890,"POBFEM":62258,"POBMAS":64002,"PEA":66727,"TVIVPARHAB":37918,"VPH_RADIO":21590,"VPH_TV":34092,"VPH_PC":17194,"VPH_TELEF":16690,"VPH_CEL":34770,"VPH_INTER":25658,"VPH_STVP":23228,"VPH_SPMVPI":10955,"VPH_CVJ":5763},{"ENTIDAD":2,"NOM_ENT":"Baja California","MUN":4,"NOM_MUN":"Tijuana","POBTOT":1922518,"POBFEM":953320 ...

# %%
resultado_json = json.loads(resultado_json)

# %%
resultado_json
# Out:
# [{'ENTIDAD': 1,
#   'NOM_ENT': 'Aguascalientes',
#   'MUN': 1,
#   'NOM_MUN': 'Aguascalientes',
#   'POBTOT': 948990,
#   'POBFEM': 486138,
#   'POBMAS': 460305,
#   'PEA': 485108,
#   'TVIVPARHAB': 266427,
#   'VPH_RADIO': 221026,
#   'VPH_TV': 256747,
#   'VPH_PC': 136845,
#   'VPH_TELEF': 116612,
#   'VPH_CEL': 251390,
#   'VPH_INTER': 178518,
#   'VPH_STVP': 130206,
#   'VPH_SPMVPI': 80923,
#   'VPH_CVJ': 56106},
#  {'ENTIDAD': 1,
#   'NOM_ENT': 'Aguascalientes',
#   'MUN': 2,
#   'NOM_MUN': 'Asientos',
#   'POBTOT': 51536,
#   'POBFEM': 26097,
#   'POBMAS': 25079,
#   'PEA': 21269,
#   'TVIVPARHAB': 12442,
#   'VPH_RADIO': 8821,
#   'VPH_TV': 11707,
#   'VPH_PC': 2794,
#   'VPH_TELEF': 1685,
#   'VPH_CEL': 10592,
#   'VPH_INTER': 4494,
#   'VPH_STVP': 3848,
#   'VPH_SPMVPI': 590,
#   'VPH_CVJ': 551},
#  {'ENTIDAD': 1,
#   'NOM_ENT': 'Aguascalientes',
#   'MUN': 3,
#   'NOM_MUN': 'Calvillo',
#   'POBTOT': 58250,
#   'POBFEM': 29584,
#   'POBMAS': 28430,
#   'PEA': 25854,
#   'TVIVPARHAB': 15471,
#   'VPH_RADIO': 10658,
#   'VPH_TV': 14566,
#   'VPH_PC': 3994,
#   'VPH_TELEF': 4715,
#   'VPH_CEL': 13602,
#   'VPH_INTER': 6537,
#   'VPH_STVP': 4736,
#   'VPH_SPMVPI': 1380,
#   'VPH_CVJ': 1350},
#  {'ENTIDAD': 1,
#   'NOM_ENT': 'Aguascalientes',
#   'MUN': 4,
#   'NOM_MUN': 'Cosío',
#   'POBTOT': 17000,
#   'POBFEM': 8626,
#   'POBMAS': 8187,
#   'PEA': 6919,
#   'TVIVPARHAB': 3887,
#   'VPH_RADIO': 2711,
#   'VPH_TV': 3629,
#   'VPH_PC': 996,
#   'VPH_TELEF': 549,
#   'VPH_CEL': 3380,
#   'VPH_INTER': 1725,
#   'VPH_STVP': 1650,
#   'VPH_SPMVPI': 221,
#   'VPH_CVJ': 190},
#  {'ENTIDAD': 1,
#   'NOM_ENT': 'Aguascalientes',
#   'MUN': 5,
#   'NOM_MUN': 'Jesús María',
#   'POBTOT': 129929,
#   'POBFEM': 65492,
#   'POBMAS': 63978,
#   'PEA': 65608,
#   'TVIVPARHAB': 33101,
#   'VPH_RADIO': 27184,
#   'VPH_TV': 31811,
#   'VPH_PC': 15659,
#   'VPH_TELEF': 12479,
#   'VPH_CEL': 31302,
#   'VPH_INTER': 19879,
#   'VPH_STVP': 13441,
#   'VPH_SPMVPI': 9283,
#   'VPH_CVJ': 6570},
#  {'ENTIDAD': 1,
#   'NOM_ENT': 'Aguascalientes',
#   'MUN': 6,
#   'NOM_MUN': 'Pabellón de Arteaga',
#   'POBTOT': 47646,
#   'POBFEM': 24000,
#   'POBMAS': 23072,
#   'PEA': 21829,
#   'TVIVPARHAB': 11311,
#   'VPH_RADIO': 8684,
#   'VPH_TV': 10863,
#   'VPH_PC': 4414,
#   'VPH_TELEF': 3585,
#   'VPH_CEL': 10213,
#   'VPH_INTER': 6166,
#   'VPH_STVP': 4677,
#   'VPH_SPMVPI': 1917,
#   'VPH_CVJ': 1340},
#  {'ENTIDAD': 1,
#   'NOM_ENT': 'Aguascalientes',
#   'MUN': 7,
#   'NOM_MUN': 'Rincón de Romos',
#   'POBTOT': 57369,
#   'POBFEM': 28845,
#   'POBMAS': 27637,
#   'PEA': 26198,
#   'TVIVPARHAB': 13356,
#   'VPH_RADIO': 9862,
#   'VPH_TV': 12590,
#   'VPH_PC': 4413,
#   'VPH_TELEF': 3220,
#   'VPH_CEL': 11976,
#   'VPH_INTER': 6233,
#   'VPH_STVP': 4491,
#   'VPH_SPMVPI': 1555,
#   'VPH_CVJ': 1347},
#  {'ENTIDAD': 1,
#   'NOM_ENT': 'Aguascalientes',
#   'MUN': 8,
#   'NOM_MUN': 'San José de Gracia',
#   'POBTOT': 9552,
#   'POBFEM': 4995,
#   'POBMAS': 4506,
#   'PEA': 3811,
#   'TVIVPARHAB': 2367,
#   'VPH_RADIO': 1642,
#   'VPH_TV': 2148,
#   'VPH_PC': 574,
#   'VPH_TELEF': 472,
#   'VPH_CEL': 2088,
#   'VPH_INTER': 728,
#   'VPH_STVP': 1275,
#   'VPH_SPMVPI': 161,
#   'VPH_CVJ': 113},
#  {'ENTIDAD': 1,
#   'NOM_ENT': 'Aguascalientes',
#   'MUN': 9,
#   'NOM_MUN': 'Tepezalá',
#   'POBTOT': 22485,
#   'POBFEM': 11244,
#   'POBMAS': 10961,
#   'PEA': 9055,
#   'TVIVPARHAB': 5347,
#   'VPH_RADIO': 3882,
#   'VPH_TV': 5034,
#   'VPH_PC': 1160,
#   'VPH_TELEF': 589,
#   'VPH_CEL': 4542,
#   'VPH_INTER': 2038,
#   'VPH_STVP': 1305,
#   'VPH_SPMVPI': 256,
#   'VPH_CVJ': 235},
#  {'ENTIDAD': 1,
#   'NOM_ENT': 'Aguascalientes',
#   'MUN': 10,
#   'NOM_MUN': 'El Llano',
#   'POBTOT': 20849,
#   'POBFEM': 10227,
#   'POBMAS': 9769,
#   'PEA': 8087,
#   'TVIVPARHAB': 5103,
#   'VPH_RADIO': 3561,
#   'VPH_TV': 4823,
#   'VPH_PC': 1026,
#   'VPH_TELEF': 449,
#   'VPH_CEL': 4376,
#   'VPH_INTER': 1306,
#   'VPH_STVP': 981,
#   'VPH_SPMVPI': 242,
#   'VPH_CVJ': 209},
#  {'ENTIDAD': 1,
#   'NOM_ENT': 'Aguascalientes',
#   'MUN': 11,
#   'NOM_MUN': 'San Francisco de los Romo',
#   'POBTOT': 61997,
#   'POBFEM': 31153,
#   'POBMAS': 30560,
#   'PEA': 29363,
#   'TVIVPARHAB': 16307,
#   'VPH_RADIO': 12916,
#   'VPH_TV': 15343,
#   'VPH_PC': 4993,
#   'VPH_TELEF': 3383,
#   'VPH_CEL': 15230,
#   'VPH_INTER': 8028,
#   'VPH_STVP': 7111,
#   'VPH_SPMVPI': 2113,
#   'VPH_CVJ': 2036},
#  {'ENTIDAD': 2,
#   'NOM_ENT': 'Baja California',
#   'MUN': 6,
#   'NOM_MUN': 'San Quintín',
#   'POBTOT': 117553,
#   'POBFEM': 57262,
#   'POBMAS': 59045,
#   'PEA': 58438,
#   'TVIVPARHAB': 32304,
#   'VPH_RADIO': 14603,
#   'VPH_TV': 23978,
#   'VPH_PC': 8050,
#   'VPH_TELEF': 4901,
#   'VPH_CEL': 29949,
#   'VPH_INTER': 11557,
#   'VPH_STVP': 16872,
#   'VPH_SPMVPI': 3269,
#   'VPH_CVJ': 1799},
#  {'ENTIDAD': 2,
#   'NOM_ENT': 'Baja California',
#   'MUN': 5,
#   'NOM_MUN': 'Playas de Rosarito',
#   'POBTOT': 126890,
#   'POBFEM': 62258,
#   'POBMAS': 64002,
#   'PEA': 66727,
#   'TVIVPARHAB': 37918,
#   'VPH_RADIO': 21590,
#   'VPH_TV': 34092,
#   'VPH_PC': 17194,
#   'VPH_TELEF': 16690,
#   'VPH_CEL': 34770,
#   'VPH_INTER': 25658,
#   'VPH_STVP': 23228,
#   'VPH_SPMVPI': 10955,
#   'VPH_CVJ': 5763},
#  {'ENTIDAD': 2,
#   'NOM_ENT': 'Baja California',
#   'MUN': 4,
#   'NOM_MUN': 'Tijuana',
#   'POBTOT': 1922518,
#   'POBFEM': 953320,
#   'POBMAS': 968110,
#   'PEA': 1050795,
#   'TVIVPARHAB': 576370,
#   'VPH_RADIO': 385369,
#   'VPH_TV': 542703,
#   'VPH_PC': 300550,
#   'VPH_TELEF': 300662,
#   'VPH_CEL': 545485,
#   'VPH_INTER': 423029,
#   'VPH_STVP': 316207,
#   'VPH_SPMVPI': 204527,
#   'VPH_CVJ': 114366},
#  {'ENTIDAD': 2,
#   'NOM_ENT': 'Baja California',
#   'MUN': 3,
#   'NOM_MUN': 'Tecate',
#   'POBTOT': 108430,
#   'POBFEM': 50631,
#   'POBMAS': 56236,
#   'PEA': 51955,
#   'TVIVPARHAB': 30574,
#   'VPH_RADIO': 18489,
#   'VPH_TV': 28413,
#   'VPH_PC': 14567,
#   'VPH_TELEF': 14735,
#   'VPH_CEL': 28378,
#   'VPH_INTER': 20200,
#   'VPH_STVP': 18005,
#   'VPH_SPMVPI': 9278,
#   'VPH_CVJ': 5389},
#  {'ENTIDAD': 2,
#   'NOM_ENT': 'Baja California',
#   'MUN': 2,
#   'NOM_MUN': 'Mexicali',
#   'POBTOT': 1049771,
#   'POBFEM': 518195,
#   'POBMAS': 525488,
#   'PEA': 546192,
#   'TVIVPARHAB': 328660,
#   'VPH_RADIO': 211714,
#   'VPH_TV': 312300,
#   'VPH_PC': 166429,
#   'VPH_TELEF': 173587,
#   'VPH_CEL': 307686,
#   'VPH_INTER': 226199,
#   'VPH_STVP': 161765,
#   'VPH_SPMVPI': 110431,
#   'VPH_CVJ': 64956},
#  {'ENTIDAD': 2,
#   'NOM_ENT': 'Baja California',
#   'MUN': 1,
#   'NOM_MUN': 'Ensenada',
#   'POBTOT': 443759,
#   'POBFEM': 220636,
#   'POBMAS': 218906,
#   'PEA': 229119,
#   'TVIVPARHAB': 138348,
#   'VPH_RADIO': 85829,
#   'VPH_TV': 126241,
#   'VPH_PC': 68585,
#   'VPH_TELEF': 65793,
#   'VPH_CEL': 129772,
#   'VPH_INTER': 92328,
#   'VPH_STVP': 80032,
#   'VPH_SPMVPI': 45140,
#   'VPH_CVJ': 24286},
#  {'ENTIDAD': 3,
#   'NOM_ENT': 'Baja California Sur',
#   'MUN': 1,
#   'NOM_MUN': 'Comondú',
#   'POBTOT': 73021,
#   'POBFEM': 35531,
#   'POBMAS': 35775,
#   'PEA': 34774,
#   'TVIVPARHAB': 21633,
#   'VPH_RADIO': 11949,
#   'VPH_TV': 19803,
#   'VPH_PC': 7400,
#   'VPH_TELEF': 6165,
#   'VPH_CEL': 19878,
#   'VPH_INTER': 10053,
#   'VPH_STVP': 13304,
#   'VPH_SPMVPI': 3335,
#   'VPH_CVJ': 1966},
#  {'ENTIDAD': 3,
#   'NOM_ENT': 'Baja California Sur',
#   'MUN': 2,
#   'NOM_MUN': 'Mulegé',
#   'POBTOT': 64019,
#   'POBFEM': 30466,
#   'POBMAS': 32267,
#   'PEA': 32198,
#   'TVIVPARHAB': 19047,
#   'VPH_RADIO': 9607,
#   'VPH_TV': 16153,
#   'VPH_PC': 7828,
#   'VPH_TELEF': 6442,
#   'VPH_CEL': 17573,
#   'VPH_INTER': 9716,
#   'VPH_STVP': 12270,
#   'VPH_SPMVPI': 4298,
#   'VPH_CVJ': 2569},
#  {'ENTIDAD': 3,
#   'NOM_ENT': 'Baja California Sur',
#   'MUN': 3,
#   'NOM_MUN': 'La Paz',
#   'POBTOT': 292241,
#   'POBFEM': 145229,
#   'POBMAS': 144225,
#   'PEA': 153083,
#   'TVIVPARHAB': 90342,
#   'VPH_RADIO': 60103,
#   'VPH_TV': 83596,
#   'VPH_PC': 49442,
#   'VPH_TELEF': 42792,
#   'VPH_CEL': 86013,
#   'VPH_INTER': 62915,
#   'VPH_STVP': 54713,
#   'VPH_SPMVPI': 30916,
#   'VPH_CVJ': 17198},
#  {'ENTIDAD': 3,
#   'NOM_ENT': 'Baja California Sur',
#   'MUN': 8,
#   'NOM_MUN': 'Los Cabos',
#   'POBTOT': 351111,
#   'POBFEM': 169688,
#   'POBMAS': 179848,
#   'PEA': 193511,
#   'TVIVPARHAB': 101549,
#   'VPH_RADIO': 56595,
#   'VPH_TV': 88219,
#   'VPH_PC': 41789,
#   'VPH_TELEF': 34480,
#   'VPH_CEL': 96152,
#   'VPH_INTER': 63265,
#   'VPH_STVP': 51473,
#   'VPH_SPMVPI': 28305,
#   'VPH_CVJ': 13882},
#  {'ENTIDAD': 3,
#   'NOM_ENT': 'Baja California Sur',
#   'MUN': 9,
#   'NOM_MUN': 'Loreto',
#   'POBTOT': 18052,
#   'POBFEM': 8650,
#   'POBMAS': 9022,
#   'PEA': 8858,
#   'TVIVPARHAB': 5513,
#   'VPH_RADIO': 3333,
#   'VPH_TV': 4974,
#   'VPH_PC': 2275,
#   'VPH_TELEF': 1682,
#   'VPH_CEL': 5045,
#   'VPH_INTER': 2490,
#   'VPH_STVP': 3650,
#   'VPH_SPMVPI': 1045,
#   'VPH_CVJ': 546},
#  {'ENTIDAD': 4,
#   'NOM_ENT': 'Campeche',
#   'MUN': 12,
#   'NOM_MUN': 'Seybaplaya',
#   'POBTOT': 15297,
#   'POBFEM': 7642,
#   'POBMAS': 7608,
#   'PEA': 6751,
#   'TVIVPARHAB': 4258,
#   'VPH_RADIO': 1609,
#   'VPH_TV': 3899,
#   'VPH_PC': 1059,
#   'VPH_TELEF': 567,
#   'VPH_CEL': 3555,
#   'VPH_INTER': 959,
#   'VPH_STVP': 3002,
#   'VPH_SPMVPI': 200,
#   'VPH_CVJ': 109},
#  {'ENTIDAD': 4,
#   'NOM_ENT': 'Campeche',
#   'MUN': 11,
#   'NOM_MUN': 'Candelaria',
#   'POBTOT': 46913,
#   'POBFEM': 22458,
#   'POBMAS': 22765,
#   'PEA': 22710,
#   'TVIVPARHAB': 12791,
#   'VPH_RADIO': 3095,
#   'VPH_TV': 9240,
#   'VPH_PC': 1254,
#   'VPH_TELEF': 1228,
#   'VPH_CEL': 7290,
#   'VPH_INTER': 1417,
#   'VPH_STVP': 6121,
#   'VPH_SPMVPI': 208,
#   'VPH_CVJ': 118},
#  {'ENTIDAD': 4,
#   'NOM_ENT': 'Campeche',
#   'MUN': 10,
#   'NOM_MUN': 'Calakmul',
#   'POBTOT': 31714,
#   'POBFEM': 15441,
#   'POBMAS': 15882,
#   'PEA': 15121,
#   'TVIVPARHAB': 7917,
#   'VPH_RADIO': 1443,
#   'VPH_TV': 5555,
#   'VPH_PC': 624,
#   'VPH_TELEF': 189,
#   'VPH_CEL': 5191,
#   'VPH_INTER': 690,
#   'VPH_STVP': 4282,
#   'VPH_SPMVPI': 48,
#   'VPH_CVJ': 42},
#  {'ENTIDAD': 4,
#   'NOM_ENT': 'Campeche',
#   'MUN': 9,
#   'NOM_MUN': 'Escárcega',
#   'POBTOT': 59920,
#   'POBFEM': 30135,
#   'POBMAS': 29045,
#   'PEA': 28645,
#   'TVIVPARHAB': 16583,
#   'VPH_RADIO': 7174,
#   'VPH_TV': 13825,
#   'VPH_PC': 3306,
#   'VPH_TELEF': 2298,
#   'VPH_CEL': 13290,
#   'VPH_INTER': 3869,
#   'VPH_STVP': 6829,
#   'VPH_SPMVPI': 778,
#   'VPH_CVJ': 404},
#  {'ENTIDAD': 4,
#   'NOM_ENT': 'Campeche',
#   'MUN': 8,
#   'NOM_MUN': 'Tenabo',
#   'POBTOT': 11452,
#   'POBFEM': 5639,
#   'POBMAS': 5771,
#   'PEA': 5794,
#   'TVIVPARHAB': 3051,
#   'VPH_RADIO': 1203,
#   'VPH_TV': 2676,
#   'VPH_PC': 504,
#   'VPH_TELEF': 67,
#   'VPH_CEL': 2331,
#   'VPH_INTER': 482,
#   'VPH_STVP': 1940,
#   'VPH_SPMVPI': 54,
#   'VPH_CVJ': 40},
#  {'ENTIDAD': 4,
#   'NOM_ENT': 'Campeche',
#   'MUN': 7,
#   'NOM_MUN': 'Palizada',
#   'POBTOT': 8683,
#   'POBFEM': 4102,
#   'POBMAS': 4218,
#   'PEA': 3740,
#   'TVIVPARHAB': 2441,
#   'VPH_RADIO': 1259,
#   'VPH_TV': 2030,
#   'VPH_PC': 380,
#   'VPH_TELEF': 235,
#   'VPH_CEL': 1938,
#   'VPH_INTER': 605,
#   'VPH_STVP': 1683,
#   'VPH_SPMVPI': 90,
#   'VPH_CVJ': 44},
#  {'ENTIDAD': 4,
#   'NOM_ENT': 'Campeche',
#   'MUN': 4,
#   'NOM_MUN': 'Champotón',
#   'POBTOT': 78170,
#   'POBFEM': 38874,
#   'POBMAS': 38669,
#   'PEA': 37265,
#   'TVIVPARHAB': 21232,
#   'VPH_RADIO': 9689,
#   'VPH_TV': 17702,
#   'VPH_PC': 3813,
#   'VPH_TELEF': 3001,
#   'VPH_CEL': 17073,
#   'VPH_INTER': 6055,
#   'VPH_STVP': 13649,
#   'VPH_SPMVPI': 1115,
#   'VPH_CVJ': 503},
#  {'ENTIDAD': 4,
#   'NOM_ENT': 'Campeche',
#   'MUN': 5,
#   'NOM_MUN': 'Hecelchakán',
#   'POBTOT': 31917,
#   'POBFEM': 16180,
#   'POBMAS': 15688,
#   'PEA': 15250,
#   'TVIVPARHAB': 8279,
#   'VPH_RADIO': 3852,
#   'VPH_TV': 7238,
#   'VPH_PC': 1973,
#   'VPH_TELEF': 476,
#   'VPH_CEL': 6144,
#   'VPH_INTER': 2471,
#   'VPH_STVP': 5920,
#   'VPH_SPMVPI': 344,
#   'VPH_CVJ': 151},
#  {'ENTIDAD': 4,
#   'NOM_ENT': 'Campeche',
#   'MUN': 3,
#   'NOM_MUN': 'Carmen',
#   'POBTOT': 248842,
#   'POBFEM': 124754,
#   'POBMAS': 121701,
#   'PEA': 123947,
#   'TVIVPARHAB': 71342,
#   'VPH_RADIO': 41111,
#   'VPH_TV': 63430,
#   'VPH_PC': 29601,
#   'VPH_TELEF': 27776,
#   'VPH_CEL': 64005,
#   'VPH_INTER': 39221,
#   'VPH_STVP': 43975,
#   'VPH_SPMVPI': 15469,
#   'VPH_CVJ': 7467},
#  {'ENTIDAD': 4,
#   'NOM_ENT': 'Campeche',
#   'MUN': 2,
#   'NOM_MUN': 'Campeche',
#   'POBTOT': 294073,
#   'POBFEM': 152330,
#   'POBMAS': 140992,
#   'PEA': 148899,
#   'TVIVPARHAB': 85140,
#   'VPH_RADIO': 55474,
#   'VPH_TV': 78363,
#   'VPH_PC': 39342,
#   'VPH_TELEF': 30764,
#   'VPH_CEL': 77950,
#   'VPH_INTER': 51958,
#   'VPH_STVP': 46597,
#   'VPH_SPMVPI': 19198,
#   'VPH_CVJ': 8591},
#  {'ENTIDAD': 4,
#   'NOM_ENT': 'Campeche',
#   'MUN': 1,
#   'NOM_MUN': 'Calkiní',
#   'POBTOT': 59232,
#   'POBFEM': 29996,
#   'POBMAS': 29092,
#   'PEA': 30030,
#   'TVIVPARHAB': 15245,
#   'VPH_RADIO': 6723,
#   'VPH_TV': 13562,
#   'VPH_PC': 4340,
#   'VPH_TELEF': 1553,
#   'VPH_CEL': 11877,
#   'VPH_INTER': 4618,
#   'VPH_STVP': 10522,
#   'VPH_SPMVPI': 811,
#   'VPH_CVJ': 379},
#  {'ENTIDAD': 4,
#   'NOM_ENT': 'Campeche',
#   'MUN': 6,
#   'NOM_MUN': 'Hopelchén',
#   'POBTOT': 42140,
#   'POBFEM': 20750,
#   'POBMAS': 21245,
#   'PEA': 20084,
#   'TVIVPARHAB': 10195,
#   'VPH_RADIO': 2875,
#   'VPH_TV': 7350,
#   'VPH_PC': 1412,
#   'VPH_TELEF': 476,
#   'VPH_CEL': 6220,
#   'VPH_INTER': 1500,
#   'VPH_STVP': 6262,
#   'VPH_SPMVPI': 163,
#   'VPH_CVJ': 116},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 22,
#   'NOM_MUN': 'Nava',
#   'POBTOT': 33129,
#   'POBFEM': 16431,
#   'POBMAS': 16463,
#   'PEA': 12977,
#   'TVIVPARHAB': 9283,
#   'VPH_RADIO': 7014,
#   'VPH_TV': 8820,
#   'VPH_PC': 3179,
#   'VPH_TELEF': 3306,
#   'VPH_CEL': 8571,
#   'VPH_INTER': 4435,
#   'VPH_STVP': 5323,
#   'VPH_SPMVPI': 1466,
#   'VPH_CVJ': 1011},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 23,
#   'NOM_MUN': 'Ocampo',
#   'POBTOT': 9642,
#   'POBFEM': 4588,
#   'POBMAS': 4846,
#   'PEA': 3604,
#   'TVIVPARHAB': 2560,
#   'VPH_RADIO': 1157,
#   'VPH_TV': 2310,
#   'VPH_PC': 569,
#   'VPH_TELEF': 455,
#   'VPH_CEL': 2082,
#   'VPH_INTER': 751,
#   'VPH_STVP': 1931,
#   'VPH_SPMVPI': 168,
#   'VPH_CVJ': 129},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 24,
#   'NOM_MUN': 'Parras',
#   'POBTOT': 44465,
#   'POBFEM': 21817,
#   'POBMAS': 22338,
#   'PEA': 21259,
#   'TVIVPARHAB': 12599,
#   'VPH_RADIO': 9911,
#   'VPH_TV': 11904,
#   'VPH_PC': 3648,
#   'VPH_TELEF': 3756,
#   'VPH_CEL': 10757,
#   'VPH_INTER': 4727,
#   'VPH_STVP': 5535,
#   'VPH_SPMVPI': 1145,
#   'VPH_CVJ': 851},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 25,
#   'NOM_MUN': 'Piedras Negras',
#   'POBTOT': 176327,
#   'POBFEM': 87453,
#   'POBMAS': 87750,
#   'PEA': 84563,
#   'TVIVPARHAB': 51642,
#   'VPH_RADIO': 39726,
#   'VPH_TV': 49765,
#   'VPH_PC': 22718,
#   'VPH_TELEF': 27650,
#   'VPH_CEL': 48358,
#   'VPH_INTER': 34470,
#   'VPH_STVP': 28742,
#   'VPH_SPMVPI': 12764,
#   'VPH_CVJ': 7952},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 26,
#   'NOM_MUN': 'Progreso',
#   'POBTOT': 3239,
#   'POBFEM': 1593,
#   'POBMAS': 1601,
#   'PEA': 1000,
#   'TVIVPARHAB': 957,
#   'VPH_RADIO': 667,
#   'VPH_TV': 868,
#   'VPH_PC': 118,
#   'VPH_TELEF': 243,
#   'VPH_CEL': 803,
#   'VPH_INTER': 199,
#   'VPH_STVP': 586,
#   'VPH_SPMVPI': 16,
#   'VPH_CVJ': 17},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 27,
#   'NOM_MUN': 'Ramos Arizpe',
#   'POBTOT': 122243,
#   'POBFEM': 59345,
#   'POBMAS': 61325,
#   'PEA': 60002,
#   'TVIVPARHAB': 34233,
#   'VPH_RADIO': 23667,
#   'VPH_TV': 32217,
#   'VPH_PC': 13687,
#   'VPH_TELEF': 11779,
#   'VPH_CEL': 31999,
#   'VPH_INTER': 19153,
#   'VPH_STVP': 16965,
#   'VPH_SPMVPI': 7902,
#   'VPH_CVJ': 5123},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 28,
#   'NOM_MUN': 'Sabinas',
#   'POBTOT': 64811,
#   'POBFEM': 32514,
#   'POBMAS': 32128,
#   'PEA': 29879,
#   'TVIVPARHAB': 20124,
#   'VPH_RADIO': 15088,
#   'VPH_TV': 19258,
#   'VPH_PC': 8336,
#   'VPH_TELEF': 11149,
#   'VPH_CEL': 18264,
#   'VPH_INTER': 11915,
#   'VPH_STVP': 12062,
#   'VPH_SPMVPI': 4319,
#   'VPH_CVJ': 2686},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 29,
#   'NOM_MUN': 'Sacramento',
#   'POBTOT': 2471,
#   'POBFEM': 1215,
#   'POBMAS': 1222,
#   'PEA': 882,
#   'TVIVPARHAB': 710,
#   'VPH_RADIO': 493,
#   'VPH_TV': 678,
#   'VPH_PC': 156,
#   'VPH_TELEF': 46,
#   'VPH_CEL': 664,
#   'VPH_INTER': 90,
#   'VPH_STVP': 510,
#   'VPH_SPMVPI': 21,
#   'VPH_CVJ': 29},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 31,
#   'NOM_MUN': 'San Buenaventura',
#   'POBTOT': 24759,
#   'POBFEM': 12394,
#   'POBMAS': 12135,
#   'PEA': 10516,
#   'TVIVPARHAB': 7528,
#   'VPH_RADIO': 5559,
#   'VPH_TV': 7220,
#   'VPH_PC': 2539,
#   'VPH_TELEF': 2401,
#   'VPH_CEL': 6901,
#   'VPH_INTER': 2714,
#   'VPH_STVP': 4075,
#   'VPH_SPMVPI': 885,
#   'VPH_CVJ': 709},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 32,
#   'NOM_MUN': 'San Juan de Sabinas',
#   'POBTOT': 42260,
#   'POBFEM': 21283,
#   'POBMAS': 20832,
#   'PEA': 18447,
#   'TVIVPARHAB': 13036,
#   'VPH_RADIO': 10270,
#   'VPH_TV': 12543,
#   'VPH_PC': 4931,
#   'VPH_TELEF': 6906,
#   'VPH_CEL': 11486,
#   'VPH_INTER': 7414,
#   'VPH_STVP': 7672,
#   'VPH_SPMVPI': 2337,
#   'VPH_CVJ': 1259},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 33,
#   'NOM_MUN': 'San Pedro',
#   'POBTOT': 101041,
#   'POBFEM': 50853,
#   'POBMAS': 49607,
#   'PEA': 42644,
#   'TVIVPARHAB': 26403,
#   'VPH_RADIO': 17903,
#   'VPH_TV': 24954,
#   'VPH_PC': 5804,
#   'VPH_TELEF': 4020,
#   'VPH_CEL': 22950,
#   'VPH_INTER': 8803,
#   'VPH_STVP': 13437,
#   'VPH_SPMVPI': 2133,
#   'VPH_CVJ': 1464},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 34,
#   'NOM_MUN': 'Sierra Mojada',
#   'POBTOT': 6741,
#   'POBFEM': 3153,
#   'POBMAS': 3428,
#   'PEA': 2521,
#   'TVIVPARHAB': 1858,
#   'VPH_RADIO': 1271,
#   'VPH_TV': 1733,
#   'VPH_PC': 513,
#   'VPH_TELEF': 275,
#   'VPH_CEL': 1545,
#   'VPH_INTER': 558,
#   'VPH_STVP': 1438,
#   'VPH_SPMVPI': 78,
#   'VPH_CVJ': 177},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 35,
#   'NOM_MUN': 'Torreón',
#   'POBTOT': 720848,
#   'POBFEM': 369062,
#   'POBMAS': 351707,
#   'PEA': 358220,
#   'TVIVPARHAB': 215017,
#   'VPH_RADIO': 152213,
#   'VPH_TV': 208578,
#   'VPH_PC': 99158,
#   'VPH_TELEF': 85109,
#   'VPH_CEL': 199135,
#   'VPH_INTER': 136172,
#   'VPH_STVP': 107880,
#   'VPH_SPMVPI': 57428,
#   'VPH_CVJ': 35719},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 36,
#   'NOM_MUN': 'Viesca',
#   'POBTOT': 20305,
#   'POBFEM': 10028,
#   'POBMAS': 10166,
#   'PEA': 7943,
#   'TVIVPARHAB': 5321,
#   'VPH_RADIO': 3065,
#   'VPH_TV': 4897,
#   'VPH_PC': 520,
#   'VPH_TELEF': 505,
#   'VPH_CEL': 4280,
#   'VPH_INTER': 561,
#   'VPH_STVP': 2184,
#   'VPH_SPMVPI': 72,
#   'VPH_CVJ': 123},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 37,
#   'NOM_MUN': 'Villa Unión',
#   'POBTOT': 6183,
#   'POBFEM': 3016,
#   'POBMAS': 3052,
#   'PEA': 2318,
#   'TVIVPARHAB': 1764,
#   'VPH_RADIO': 1386,
#   'VPH_TV': 1645,
#   'VPH_PC': 358,
#   'VPH_TELEF': 498,
#   'VPH_CEL': 1578,
#   'VPH_INTER': 535,
#   'VPH_STVP': 1182,
#   'VPH_SPMVPI': 104,
#   'VPH_CVJ': 118},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 21,
#   'NOM_MUN': 'Nadadores',
#   'POBTOT': 6539,
#   'POBFEM': 3258,
#   'POBMAS': 3193,
#   'PEA': 2657,
#   'TVIVPARHAB': 1936,
#   'VPH_RADIO': 1431,
#   'VPH_TV': 1822,
#   'VPH_PC': 468,
#   'VPH_TELEF': 336,
#   'VPH_CEL': 1777,
#   'VPH_INTER': 435,
#   'VPH_STVP': 1070,
#   'VPH_SPMVPI': 150,
#   'VPH_CVJ': 117},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 30,
#   'NOM_MUN': 'Saltillo',
#   'POBTOT': 879958,
#   'POBFEM': 441905,
#   'POBMAS': 437410,
#   'PEA': 423665,
#   'TVIVPARHAB': 242379,
#   'VPH_RADIO': 176003,
#   'VPH_TV': 233399,
#   'VPH_PC': 117989,
#   'VPH_TELEF': 125917,
#   'VPH_CEL': 223943,
#   'VPH_INTER': 165010,
#   'VPH_STVP': 106509,
#   'VPH_SPMVPI': 66996,
#   'VPH_CVJ': 41295},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 20,
#   'NOM_MUN': 'Múzquiz',
#   'POBTOT': 71610,
#   'POBFEM': 35577,
#   'POBMAS': 35519,
#   'PEA': 28598,
#   'TVIVPARHAB': 20219,
#   'VPH_RADIO': 14505,
#   'VPH_TV': 19079,
#   'VPH_PC': 5862,
#   'VPH_TELEF': 7806,
#   'VPH_CEL': 17706,
#   'VPH_INTER': 8628,
#   'VPH_STVP': 13507,
#   'VPH_SPMVPI': 2086,
#   'VPH_CVJ': 1584},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 38,
#   'NOM_MUN': 'Zaragoza',
#   'POBTOT': 13129,
#   'POBFEM': 6454,
#   'POBMAS': 6293,
#   'PEA': 5430,
#   'TVIVPARHAB': 3807,
#   'VPH_RADIO': 3010,
#   'VPH_TV': 3563,
#   'VPH_PC': 1019,
#   'VPH_TELEF': 1510,
#   'VPH_CEL': 3288,
#   'VPH_INTER': 1470,
#   'VPH_STVP': 2429,
#   'VPH_SPMVPI': 477,
#   'VPH_CVJ': 306},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 18,
#   'NOM_MUN': 'Monclova',
#   'POBTOT': 237951,
#   'POBFEM': 119787,
#   'POBMAS': 117904,
#   'PEA': 108416,
#   'TVIVPARHAB': 69776,
#   'VPH_RADIO': 51899,
#   'VPH_TV': 67453,
#   'VPH_PC': 30280,
#   'VPH_TELEF': 38229,
#   'VPH_CEL': 64270,
#   'VPH_INTER': 44999,
#   'VPH_STVP': 38982,
#   'VPH_SPMVPI': 16583,
#   'VPH_CVJ': 10140},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 19,
#   'NOM_MUN': 'Morelos',
#   'POBTOT': 7928,
#   'POBFEM': 3933,
#   'POBMAS': 3841,
#   'PEA': 3231,
#   'TVIVPARHAB': 2288,
#   'VPH_RADIO': 1861,
#   'VPH_TV': 2194,
#   'VPH_PC': 821,
#   'VPH_TELEF': 988,
#   'VPH_CEL': 2035,
#   'VPH_INTER': 1152,
#   'VPH_STVP': 1497,
#   'VPH_SPMVPI': 395,
#   'VPH_CVJ': 236},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 1,
#   'NOM_MUN': 'Abasolo',
#   'POBTOT': 1022,
#   'POBFEM': 466,
#   'POBMAS': 509,
#   'PEA': 417,
#   'TVIVPARHAB': 347,
#   'VPH_RADIO': 243,
#   'VPH_TV': 335,
#   'VPH_PC': 76,
#   'VPH_TELEF': 46,
#   'VPH_CEL': 303,
#   'VPH_INTER': 40,
#   'VPH_STVP': 178,
#   'VPH_SPMVPI': 14,
#   'VPH_CVJ': 21},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 2,
#   'NOM_MUN': 'Acuña',
#   'POBTOT': 163047,
#   'POBFEM': 80971,
#   'POBMAS': 81638,
#   'PEA': 82609,
#   'TVIVPARHAB': 47022,
#   'VPH_RADIO': 29721,
#   'VPH_TV': 44550,
#   'VPH_PC': 15151,
#   'VPH_TELEF': 12352,
#   'VPH_CEL': 44299,
#   'VPH_INTER': 21726,
#   'VPH_STVP': 20425,
#   'VPH_SPMVPI': 6675,
#   'VPH_CVJ': 4557},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 3,
#   'NOM_MUN': 'Allende',
#   'POBTOT': 23056,
#   'POBFEM': 11567,
#   'POBMAS': 11382,
#   'PEA': 9662,
#   'TVIVPARHAB': 6807,
#   'VPH_RADIO': 5346,
#   'VPH_TV': 6531,
#   'VPH_PC': 2318,
#   'VPH_TELEF': 3120,
#   'VPH_CEL': 6121,
#   'VPH_INTER': 3439,
#   'VPH_STVP': 3944,
#   'VPH_SPMVPI': 1138,
#   'VPH_CVJ': 703},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 4,
#   'NOM_MUN': 'Arteaga',
#   'POBTOT': 29578,
#   'POBFEM': 14033,
#   'POBMAS': 14345,
#   'PEA': 13156,
#   'TVIVPARHAB': 8263,
#   'VPH_RADIO': 4764,
#   'VPH_TV': 7801,
#   'VPH_PC': 2997,
#   'VPH_TELEF': 2100,
#   'VPH_CEL': 7246,
#   'VPH_INTER': 3460,
#   'VPH_STVP': 4267,
#   'VPH_SPMVPI': 1738,
#   'VPH_CVJ': 1170},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 5,
#   'NOM_MUN': 'Candela',
#   'POBTOT': 1643,
#   'POBFEM': 797,
#   'POBMAS': 836,
#   'PEA': 519,
#   'TVIVPARHAB': 468,
#   'VPH_RADIO': 290,
#   'VPH_TV': 437,
#   'VPH_PC': 73,
#   'VPH_TELEF': 85,
#   'VPH_CEL': 424,
#   'VPH_INTER': 72,
#   'VPH_STVP': 384,
#   'VPH_SPMVPI': 15,
#   'VPH_CVJ': 11},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 6,
#   'NOM_MUN': 'Castaños',
#   'POBTOT': 29128,
#   'POBFEM': 14469,
#   'POBMAS': 14494,
#   'PEA': 11644,
#   'TVIVPARHAB': 8310,
#   'VPH_RADIO': 5926,
#   'VPH_TV': 7828,
#   'VPH_PC': 2365,
#   'VPH_TELEF': 2538,
#   'VPH_CEL': 7288,
#   'VPH_INTER': 3395,
#   'VPH_STVP': 4620,
#   'VPH_SPMVPI': 776,
#   'VPH_CVJ': 674},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 8,
#   'NOM_MUN': 'Escobedo',
#   'POBTOT': 3047,
#   'POBFEM': 1505,
#   'POBMAS': 1504,
#   'PEA': 1011,
#   'TVIVPARHAB': 893,
#   'VPH_RADIO': 559,
#   'VPH_TV': 831,
#   'VPH_PC': 116,
#   'VPH_TELEF': 85,
#   'VPH_CEL': 798,
#   'VPH_INTER': 234,
#   'VPH_STVP': 539,
#   'VPH_SPMVPI': 17,
#   'VPH_CVJ': 31},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 7,
#   'NOM_MUN': 'Cuatro Ciénegas',
#   'POBTOT': 12715,
#   'POBFEM': 6276,
#   'POBMAS': 6248,
#   'PEA': 5197,
#   'TVIVPARHAB': 3702,
#   'VPH_RADIO': 2401,
#   'VPH_TV': 3467,
#   'VPH_PC': 837,
#   'VPH_TELEF': 815,
#   'VPH_CEL': 3191,
#   'VPH_INTER': 976,
#   'VPH_STVP': 2563,
#   'VPH_SPMVPI': 310,
#   'VPH_CVJ': 220},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 10,
#   'NOM_MUN': 'Frontera',
#   'POBTOT': 82409,
#   'POBFEM': 41165,
#   'POBMAS': 41168,
#   'PEA': 35969,
#   'TVIVPARHAB': 23340,
#   'VPH_RADIO': 16991,
#   'VPH_TV': 22465,
#   'VPH_PC': 7811,
#   'VPH_TELEF': 10101,
#   'VPH_CEL': 21204,
#   'VPH_INTER': 13038,
#   'VPH_STVP': 12489,
#   'VPH_SPMVPI': 3352,
#   'VPH_CVJ': 2070},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 11,
#   'NOM_MUN': 'General Cepeda',
#   'POBTOT': 11898,
#   'POBFEM': 5673,
#   'POBMAS': 5937,
#   'PEA': 4755,
#   'TVIVPARHAB': 3308,
#   'VPH_RADIO': 1105,
#   'VPH_TV': 2942,
#   'VPH_PC': 380,
#   'VPH_TELEF': 319,
#   'VPH_CEL': 2583,
#   'VPH_INTER': 485,
#   'VPH_STVP': 2308,
#   'VPH_SPMVPI': 77,
#   'VPH_CVJ': 64},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 12,
#   'NOM_MUN': 'Guerrero',
#   'POBTOT': 1643,
#   'POBFEM': 676,
#   'POBMAS': 742,
#   'PEA': 544,
#   'TVIVPARHAB': 440,
#   'VPH_RADIO': 351,
#   'VPH_TV': 395,
#   'VPH_PC': 109,
#   'VPH_TELEF': 78,
#   'VPH_CEL': 374,
#   'VPH_INTER': 88,
#   'VPH_STVP': 299,
#   'VPH_SPMVPI': 25,
#   'VPH_CVJ': 33},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 13,
#   'NOM_MUN': 'Hidalgo',
#   'POBTOT': 1735,
#   'POBFEM': 832,
#   'POBMAS': 851,
#   'PEA': 551,
#   'TVIVPARHAB': 455,
#   'VPH_RADIO': 247,
#   'VPH_TV': 429,
#   'VPH_PC': 90,
#   'VPH_TELEF': 13,
#   'VPH_CEL': 427,
#   'VPH_INTER': 75,
#   'VPH_STVP': 219,
#   'VPH_SPMVPI': 11,
#   'VPH_CVJ': 32},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 14,
#   'NOM_MUN': 'Jiménez',
#   'POBTOT': 9502,
#   'POBFEM': 4477,
#   'POBMAS': 4594,
#   'PEA': 3686,
#   'TVIVPARHAB': 2634,
#   'VPH_RADIO': 1926,
#   'VPH_TV': 2405,
#   'VPH_PC': 327,
#   'VPH_TELEF': 192,
#   'VPH_CEL': 2395,
#   'VPH_INTER': 972,
#   'VPH_STVP': 1502,
#   'VPH_SPMVPI': 72,
#   'VPH_CVJ': 97},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 15,
#   'NOM_MUN': 'Juárez',
#   'POBTOT': 1584,
#   'POBFEM': 764,
#   'POBMAS': 737,
#   'PEA': 565,
#   'TVIVPARHAB': 454,
#   'VPH_RADIO': 271,
#   'VPH_TV': 427,
#   'VPH_PC': 90,
#   'VPH_TELEF': 92,
#   'VPH_CEL': 400,
#   'VPH_INTER': 58,
#   'VPH_STVP': 318,
#   'VPH_SPMVPI': 24,
#   'VPH_CVJ': 22},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 16,
#   'NOM_MUN': 'Lamadrid',
#   'POBTOT': 1764,
#   'POBFEM': 827,
#   'POBMAS': 916,
#   'PEA': 555,
#   'TVIVPARHAB': 544,
#   'VPH_RADIO': 319,
#   'VPH_TV': 501,
#   'VPH_PC': 112,
#   'VPH_TELEF': 46,
#   'VPH_CEL': 474,
#   'VPH_INTER': 53,
#   'VPH_STVP': 428,
#   'VPH_SPMVPI': 7,
#   'VPH_CVJ': 12},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 17,
#   'NOM_MUN': 'Matamoros',
#   'POBTOT': 118337,
#   'POBFEM': 59422,
#   'POBMAS': 58140,
#   'PEA': 53876,
#   'TVIVPARHAB': 31112,
#   'VPH_RADIO': 21260,
#   'VPH_TV': 29875,
#   'VPH_PC': 8139,
#   'VPH_TELEF': 4752,
#   'VPH_CEL': 27880,
#   'VPH_INTER': 11488,
#   'VPH_STVP': 9122,
#   'VPH_SPMVPI': 2659,
#   'VPH_CVJ': 2167},
#  {'ENTIDAD': 5,
#   'NOM_ENT': 'Coahuila de Zaragoza',
#   'MUN': 9,
#   'NOM_MUN': 'Francisco I. Madero',
#   'POBTOT': 59035,
#   'POBFEM': 29720,
#   'POBMAS': 29081,
#   'PEA': 26395,
#   'TVIVPARHAB': 15830,
#   'VPH_RADIO': 10625,
#   'VPH_TV': 15150,
#   'VPH_PC': 3986,
#   'VPH_TELEF': 2366,
#   'VPH_CEL': 13961,
#   'VPH_INTER': 5404,
#   'VPH_STVP': 5395,
#   'VPH_SPMVPI': 1335,
#   'VPH_CVJ': 1069},
#  {'ENTIDAD': 6,
#   'NOM_ENT': 'Colima',
#   'MUN': 7,
#   'NOM_MUN': 'Manzanillo',
#   'POBTOT': 191031,
#   'POBFEM': 95759,
#   'POBMAS': 94658,
#   'PEA': 101061,
#   'TVIVPARHAB': 59653,
#   'VPH_RADIO': 40447,
#   'VPH_TV': 54747,
#   'VPH_PC': 23316,
#   'VPH_TELEF': 22688,
#   'VPH_CEL': 55089,
#   'VPH_INTER': 34963,
#   'VPH_STVP': 33211,
#   'VPH_SPMVPI': 11512,
#   'VPH_CVJ': 5831},
#  {'ENTIDAD': 6,
#   'NOM_ENT': 'Colima',
#   'MUN': 9,
#   'NOM_MUN': 'Tecomán',
#   'POBTOT': 116305,
#   'POBFEM': 57825,
#   'POBMAS': 56956,
#   'PEA': 60048,
#   'TVIVPARHAB': 32604,
#   'VPH_RADIO': 20927,
#   'VPH_TV': 28514,
#   'VPH_PC': 7472,
#   'VPH_TELEF': 8690,
#   'VPH_CEL': 28721,
#   'VPH_INTER': 11411,
#   'VPH_STVP': 15773,
#   'VPH_SPMVPI': 2633,
#   'VPH_CVJ': 1488},
#  {'ENTIDAD': 6,
#   'NOM_ENT': 'Colima',
#   'MUN': 8,
#   'NOM_MUN': 'Minatitlán',
#   'POBTOT': 10231,
#   'POBFEM': 4968,
#   'POBMAS': 5203,
#   'PEA': 4788,
#   'TVIVPARHAB': 2893,
#   'VPH_RADIO': 1457,
#   'VPH_TV': 2462,
#   'VPH_PC': 620,
#   'VPH_TELEF': 523,
#   'VPH_CEL': 2382,
#   'VPH_INTER': 799,
#   'VPH_STVP': 1495,
#   'VPH_SPMVPI': 175,
#   'VPH_CVJ': 121},
#  {'ENTIDAD': 6,
#   'NOM_ENT': 'Colima',
#   'MUN': 6,
#   'NOM_MUN': 'Ixtlahuacán',
#   'POBTOT': 5623,
#   'POBFEM': 2705,
#   'POBMAS': 2850,
#   'PEA': 2687,
#   'TVIVPARHAB': 1689,
#   'VPH_RADIO': 1141,
#   'VPH_TV': 1354,
#   'VPH_PC': 297,
#   'VPH_TELEF': 338,
#   'VPH_CEL': 1312,
#   'VPH_INTER': 607,
#   'VPH_STVP': 978,
#   'VPH_SPMVPI': 70,
#   'VPH_CVJ': 47},
#  {'ENTIDAD': 6,
#   'NOM_ENT': 'Colima',
#   'MUN': 10,
#   'NOM_MUN': 'Villa de Álvarez',
#   'POBTOT': 149762,
#   'POBFEM': 77349,
#   'POBMAS': 72273,
#   'PEA': 82014,
#   'TVIVPARHAB': 49027,
#   'VPH_RADIO': 34535,
#   'VPH_TV': 46038,
#   'VPH_PC': 26366,
#   'VPH_TELEF': 18990,
#   'VPH_CEL': 46543,
#   'VPH_INTER': 36754,
#   'VPH_STVP': 25145,
#   'VPH_SPMVPI': 14406,
#   'VPH_CVJ': 7617},
#  {'ENTIDAD': 6,
#   'NOM_ENT': 'Colima',
#   'MUN': 4,
#   'NOM_MUN': 'Coquimatlán',
#   'POBTOT': 20837,
#   'POBFEM': 10249,
#   'POBMAS': 10329,
#   'PEA': 10480,
#   'TVIVPARHAB': 6096,
#   'VPH_RADIO': 4204,
#   'VPH_TV': 5451,
#   'VPH_PC': 1616,
#   'VPH_TELEF': 1527,
#   'VPH_CEL': 5310,
#   'VPH_INTER': 2876,
#   'VPH_STVP': 2571,
#   'VPH_SPMVPI': 484,
#   'VPH_CVJ': 275},
#  {'ENTIDAD': 6,
#   'NOM_ENT': 'Colima',
#   'MUN': 3,
#   'NOM_MUN': 'Comala',
#   'POBTOT': 21661,
#   'POBFEM': 10657,
#   'POBMAS': 10740,
#   'PEA': 11347,
#   'TVIVPARHAB': 6201,
#   'VPH_RADIO': 4653,
#   'VPH_TV': 5502,
#   'VPH_PC': 1800,
#   'VPH_TELEF': 1882,
#   'VPH_CEL': 5179,
#   'VPH_INTER': 2940,
#   'VPH_STVP': 2315,
#   'VPH_SPMVPI': 800,
#   'VPH_CVJ': 356},
#  {'ENTIDAD': 6,
#   'NOM_ENT': 'Colima',
#   'MUN': 2,
#   'NOM_MUN': 'Colima',
#   'POBTOT': 157048,
#   'POBFEM': 80697,
#   'POBMAS': 75917,
#   'PEA': 82074,
#   'TVIVPARHAB': 50206,
#   'VPH_RADIO': 35716,
#   'VPH_TV': 46525,
#   'VPH_PC': 23953,
#   'VPH_TELEF': 20516,
#   'VPH_CEL': 46272,
#   'VPH_INTER': 34620,
#   'VPH_STVP': 24131,
#   'VPH_SPMVPI': 12139,
#   'VPH_CVJ': 6035},
#  {'ENTIDAD': 6,
#   'NOM_ENT': 'Colima',
#   'MUN': 1,
#   'NOM_MUN': 'Armería',
#   'POBTOT': 27623,
#   'POBFEM': 13598,
#   'POBMAS': 13819,
#   'PEA': 14516,
#   'TVIVPARHAB': 8152,
#   'VPH_RADIO': 5046,
#   'VPH_TV': 7048,
#   'VPH_PC': 1606,
#   'VPH_TELEF': 1955,
#   'VPH_CEL': 7062,
#   'VPH_INTER': 2625,
#   'VPH_STVP': 3909,
#   'VPH_SPMVPI': 501,
#   'VPH_CVJ': 276},
#  {'ENTIDAD': 6,
#   'NOM_ENT': 'Colima',
#   'MUN': 5,
#   'NOM_MUN': 'Cuauhtémoc',
#   'POBTOT': 31267,
#   'POBFEM': 15455,
#   'POBMAS': 15606,
#   'PEA': 15348,
#   'TVIVPARHAB': 9254,
#   'VPH_RADIO': 6322,
#   'VPH_TV': 8409,
#   'VPH_PC': 3037,
#   'VPH_TELEF': 3093,
#   'VPH_CEL': 7930,
#   'VPH_INTER': 4590,
#   'VPH_STVP': 4266,
#   'VPH_SPMVPI': 1121,
#   'VPH_CVJ': 623},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 65,
#   'NOM_MUN': 'Palenque',
#   'POBTOT': 132265,
#   'POBFEM': 66493,
#   'POBMAS': 64322,
#   'PEA': 66599,
#   'TVIVPARHAB': 33214,
#   'VPH_RADIO': 16330,
#   'VPH_TV': 25182,
#   'VPH_PC': 4164,
#   'VPH_TELEF': 1922,
#   'VPH_CEL': 22707,
#   'VPH_INTER': 5537,
#   'VPH_STVP': 11982,
#   'VPH_SPMVPI': 783,
#   'VPH_CVJ': 387},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 82,
#   'NOM_MUN': 'Sitalá',
#   'POBTOT': 15518,
#   'POBFEM': 7832,
#   'POBMAS': 7573,
#   'PEA': 3841,
#   'TVIVPARHAB': 3199,
#   'VPH_RADIO': 805,
#   'VPH_TV': 1098,
#   'VPH_PC': 39,
#   'VPH_TELEF': 9,
#   'VPH_CEL': 626,
#   'VPH_INTER': 99,
#   'VPH_STVP': 223,
#   'VPH_SPMVPI': 2,
#   'VPH_CVJ': 4},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 83,
#   'NOM_MUN': 'Socoltenango',
#   'POBTOT': 19092,
#   'POBFEM': 9603,
#   'POBMAS': 9326,
#   'PEA': 7809,
#   'TVIVPARHAB': 5018,
#   'VPH_RADIO': 3015,
#   'VPH_TV': 4245,
#   'VPH_PC': 437,
#   'VPH_TELEF': 157,
#   'VPH_CEL': 3377,
#   'VPH_INTER': 665,
#   'VPH_STVP': 1123,
#   'VPH_SPMVPI': 46,
#   'VPH_CVJ': 48},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 84,
#   'NOM_MUN': 'Solosuchiapa',
#   'POBTOT': 8561,
#   'POBFEM': 4164,
#   'POBMAS': 4292,
#   'PEA': 3484,
#   'TVIVPARHAB': 2030,
#   'VPH_RADIO': 683,
#   'VPH_TV': 1423,
#   'VPH_PC': 114,
#   'VPH_TELEF': 19,
#   'VPH_CEL': 1213,
#   'VPH_INTER': 282,
#   'VPH_STVP': 682,
#   'VPH_SPMVPI': 10,
#   'VPH_CVJ': 7},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 85,
#   'NOM_MUN': 'Soyaló',
#   'POBTOT': 10890,
#   'POBFEM': 5418,
#   'POBMAS': 5458,
#   'PEA': 4267,
#   'TVIVPARHAB': 2563,
#   'VPH_RADIO': 1082,
#   'VPH_TV': 2157,
#   'VPH_PC': 150,
#   'VPH_TELEF': 53,
#   'VPH_CEL': 2063,
#   'VPH_INTER': 278,
#   'VPH_STVP': 1195,
#   'VPH_SPMVPI': 17,
#   'VPH_CVJ': 17},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 88,
#   'NOM_MUN': 'Sunuapa',
#   'POBTOT': 2308,
#   'POBFEM': 1127,
#   'POBMAS': 1166,
#   'PEA': 838,
#   'TVIVPARHAB': 558,
#   'VPH_RADIO': 195,
#   'VPH_TV': 396,
#   'VPH_PC': 43,
#   'VPH_TELEF': 9,
#   'VPH_CEL': 403,
#   'VPH_INTER': 167,
#   'VPH_STVP': 249,
#   'VPH_SPMVPI': 2,
#   'VPH_CVJ': 5},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 87,
#   'NOM_MUN': 'Suchiate',
#   'POBTOT': 41672,
#   'POBFEM': 21030,
#   'POBMAS': 20298,
#   'PEA': 20594,
#   'TVIVPARHAB': 10958,
#   'VPH_RADIO': 5608,
#   'VPH_TV': 8758,
#   'VPH_PC': 883,
#   'VPH_TELEF': 609,
#   'VPH_CEL': 8282,
#   'VPH_INTER': 2798,
#   'VPH_STVP': 3134,
#   'VPH_SPMVPI': 273,
#   'VPH_CVJ': 162},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 89,
#   'NOM_MUN': 'Tapachula',
#   'POBTOT': 353702,
#   'POBFEM': 181688,
#   'POBMAS': 170996,
#   'PEA': 165778,
#   'TVIVPARHAB': 95997,
#   'VPH_RADIO': 58774,
#   'VPH_TV': 83625,
#   'VPH_PC': 23521,
#   'VPH_TELEF': 21704,
#   'VPH_CEL': 83262,
#   'VPH_INTER': 31760,
#   'VPH_STVP': 28266,
#   'VPH_SPMVPI': 8077,
#   'VPH_CVJ': 3677},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 90,
#   'NOM_MUN': 'Tapalapa',
#   'POBTOT': 4547,
#   'POBFEM': 2335,
#   'POBMAS': 2204,
#   'PEA': 1423,
#   'TVIVPARHAB': 1098,
#   'VPH_RADIO': 362,
#   'VPH_TV': 690,
#   'VPH_PC': 104,
#   'VPH_TELEF': 23,
#   'VPH_CEL': 545,
#   'VPH_INTER': 59,
#   'VPH_STVP': 279,
#   'VPH_SPMVPI': 3,
#   'VPH_CVJ': 5},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 91,
#   'NOM_MUN': 'Tapilula',
#   'POBTOT': 13592,
#   'POBFEM': 6988,
#   'POBMAS': 6522,
#   'PEA': 5418,
#   'TVIVPARHAB': 3437,
#   'VPH_RADIO': 1554,
#   'VPH_TV': 2804,
#   'VPH_PC': 444,
#   'VPH_TELEF': 102,
#   'VPH_CEL': 2480,
#   'VPH_INTER': 395,
#   'VPH_STVP': 1075,
#   'VPH_SPMVPI': 47,
#   'VPH_CVJ': 29},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 92,
#   'NOM_MUN': 'Tecpatán',
#   'POBTOT': 21426,
#   'POBFEM': 10579,
#   'POBMAS': 10453,
#   'PEA': 8741,
#   'TVIVPARHAB': 5684,
#   'VPH_RADIO': 1507,
#   'VPH_TV': 3706,
#   'VPH_PC': 341,
#   'VPH_TELEF': 117,
#   'VPH_CEL': 2720,
#   'VPH_INTER': 713,
#   'VPH_STVP': 2023,
#   'VPH_SPMVPI': 12,
#   'VPH_CVJ': 9},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 86,
#   'NOM_MUN': 'Suchiapa',
#   'POBTOT': 25627,
#   'POBFEM': 12733,
#   'POBMAS': 12586,
#   'PEA': 10688,
#   'TVIVPARHAB': 6283,
#   'VPH_RADIO': 3545,
#   'VPH_TV': 5464,
#   'VPH_PC': 1266,
#   'VPH_TELEF': 600,
#   'VPH_CEL': 5200,
#   'VPH_INTER': 1730,
#   'VPH_STVP': 2175,
#   'VPH_SPMVPI': 186,
#   'VPH_CVJ': 84},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 81,
#   'NOM_MUN': 'Simojovel',
#   'POBTOT': 52935,
#   'POBFEM': 26991,
#   'POBMAS': 25836,
#   'PEA': 20943,
#   'TVIVPARHAB': 10696,
#   'VPH_RADIO': 3789,
#   'VPH_TV': 6018,
#   'VPH_PC': 504,
#   'VPH_TELEF': 322,
#   'VPH_CEL': 5284,
#   'VPH_INTER': 449,
#   'VPH_STVP': 1778,
#   'VPH_SPMVPI': 87,
#   'VPH_CVJ': 46},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 78,
#   'NOM_MUN': 'San Cristóbal de las Casas',
#   'POBTOT': 215874,
#   'POBFEM': 113570,
#   'POBMAS': 102279,
#   'PEA': 114932,
#   'TVIVPARHAB': 52658,
#   'VPH_RADIO': 38769,
#   'VPH_TV': 45717,
#   'VPH_PC': 16366,
#   'VPH_TELEF': 12058,
#   'VPH_CEL': 45720,
#   'VPH_INTER': 17949,
#   'VPH_STVP': 13920,
#   'VPH_SPMVPI': 4355,
#   'VPH_CVJ': 2684},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 79,
#   'NOM_MUN': 'San Fernando',
#   'POBTOT': 41793,
#   'POBFEM': 20752,
#   'POBMAS': 20689,
#   'PEA': 19314,
#   'TVIVPARHAB': 10392,
#   'VPH_RADIO': 6400,
#   'VPH_TV': 9060,
#   'VPH_PC': 1530,
#   'VPH_TELEF': 886,
#   'VPH_CEL': 8014,
#   'VPH_INTER': 2411,
#   'VPH_STVP': 4775,
#   'VPH_SPMVPI': 371,
#   'VPH_CVJ': 223},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 77,
#   'NOM_MUN': 'Salto de Agua',
#   'POBTOT': 64251,
#   'POBFEM': 32156,
#   'POBMAS': 31639,
#   'PEA': 33596,
#   'TVIVPARHAB': 14641,
#   'VPH_RADIO': 6948,
#   'VPH_TV': 8446,
#   'VPH_PC': 570,
#   'VPH_TELEF': 300,
#   'VPH_CEL': 4662,
#   'VPH_INTER': 697,
#   'VPH_STVP': 4420,
#   'VPH_SPMVPI': 43,
#   'VPH_CVJ': 16},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 76,
#   'NOM_MUN': 'Sabanilla',
#   'POBTOT': 29889,
#   'POBFEM': 14963,
#   'POBMAS': 14919,
#   'PEA': 13544,
#   'TVIVPARHAB': 6773,
#   'VPH_RADIO': 1845,
#   'VPH_TV': 3244,
#   'VPH_PC': 90,
#   'VPH_TELEF': 25,
#   'VPH_CEL': 1500,
#   'VPH_INTER': 58,
#   'VPH_STVP': 1133,
#   'VPH_SPMVPI': 6,
#   'VPH_CVJ': 4},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 75,
#   'NOM_MUN': 'Las Rosas',
#   'POBTOT': 28829,
#   'POBFEM': 14595,
#   'POBMAS': 14005,
#   'PEA': 13905,
#   'TVIVPARHAB': 7172,
#   'VPH_RADIO': 4716,
#   'VPH_TV': 5954,
#   'VPH_PC': 624,
#   'VPH_TELEF': 386,
#   'VPH_CEL': 4623,
#   'VPH_INTER': 404,
#   'VPH_STVP': 2133,
#   'VPH_SPMVPI': 79,
#   'VPH_CVJ': 88},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 74,
#   'NOM_MUN': 'Reforma',
#   'POBTOT': 44829,
#   'POBFEM': 22921,
#   'POBMAS': 21908,
#   'PEA': 20015,
#   'TVIVPARHAB': 12520,
#   'VPH_RADIO': 5962,
#   'VPH_TV': 10800,
#   'VPH_PC': 2559,
#   'VPH_TELEF': 1651,
#   'VPH_CEL': 10789,
#   'VPH_INTER': 3840,
#   'VPH_STVP': 3835,
#   'VPH_SPMVPI': 913,
#   'VPH_CVJ': 454},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 73,
#   'NOM_MUN': 'Rayón',
#   'POBTOT': 10866,
#   'POBFEM': 5484,
#   'POBMAS': 5318,
#   'PEA': 5026,
#   'TVIVPARHAB': 2389,
#   'VPH_RADIO': 1120,
#   'VPH_TV': 1819,
#   'VPH_PC': 236,
#   'VPH_TELEF': 40,
#   'VPH_CEL': 1654,
#   'VPH_INTER': 142,
#   'VPH_STVP': 370,
#   'VPH_SPMVPI': 14,
#   'VPH_CVJ': 22},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 71,
#   'NOM_MUN': 'Villa Comaltitlán',
#   'POBTOT': 30297,
#   'POBFEM': 14624,
#   'POBMAS': 14282,
#   'PEA': 12857,
#   'TVIVPARHAB': 7616,
#   'VPH_RADIO': 4485,
#   'VPH_TV': 5978,
#   'VPH_PC': 512,
#   'VPH_TELEF': 836,
#   'VPH_CEL': 5444,
#   'VPH_INTER': 1280,
#   'VPH_STVP': 3389,
#   'VPH_SPMVPI': 95,
#   'VPH_CVJ': 61},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 70,
#   'NOM_MUN': 'El Porvenir',
#   'POBTOT': 12263,
#   'POBFEM': 6155,
#   'POBMAS': 6094,
#   'PEA': 4906,
#   'TVIVPARHAB': 2401,
#   'VPH_RADIO': 1569,
#   'VPH_TV': 1707,
#   'VPH_PC': 84,
#   'VPH_TELEF': 69,
#   'VPH_CEL': 856,
#   'VPH_INTER': 172,
#   'VPH_STVP': 400,
#   'VPH_SPMVPI': 3,
#   'VPH_CVJ': 2},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 69,
#   'NOM_MUN': 'Pijijiapan',
#   'POBTOT': 51193,
#   'POBFEM': 24933,
#   'POBMAS': 23761,
#   'PEA': 23862,
#   'TVIVPARHAB': 14202,
#   'VPH_RADIO': 7638,
#   'VPH_TV': 11653,
#   'VPH_PC': 1314,
#   'VPH_TELEF': 1392,
#   'VPH_CEL': 10485,
#   'VPH_INTER': 1980,
#   'VPH_STVP': 7757,
#   'VPH_SPMVPI': 199,
#   'VPH_CVJ': 119},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 68,
#   'NOM_MUN': 'Pichucalco',
#   'POBTOT': 31919,
#   'POBFEM': 16225,
#   'POBMAS': 15608,
#   'PEA': 15275,
#   'TVIVPARHAB': 8574,
#   'VPH_RADIO': 3696,
#   'VPH_TV': 6927,
#   'VPH_PC': 1336,
#   'VPH_TELEF': 739,
#   'VPH_CEL': 6572,
#   'VPH_INTER': 2089,
#   'VPH_STVP': 3921,
#   'VPH_SPMVPI': 412,
#   'VPH_CVJ': 166},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 67,
#   'NOM_MUN': 'Pantepec',
#   'POBTOT': 12266,
#   'POBFEM': 6194,
#   'POBMAS': 6036,
#   'PEA': 5453,
#   'TVIVPARHAB': 2928,
#   'VPH_RADIO': 1253,
#   'VPH_TV': 2067,
#   'VPH_PC': 131,
#   'VPH_TELEF': 20,
#   'VPH_CEL': 1440,
#   'VPH_INTER': 192,
#   'VPH_STVP': 869,
#   'VPH_SPMVPI': 10,
#   'VPH_CVJ': 5},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 66,
#   'NOM_MUN': 'Pantelhó',
#   'POBTOT': 26391,
#   'POBFEM': 13395,
#   'POBMAS': 12892,
#   'PEA': 7688,
#   'TVIVPARHAB': 4912,
#   'VPH_RADIO': 1426,
#   'VPH_TV': 2122,
#   'VPH_PC': 50,
#   'VPH_TELEF': 81,
#   'VPH_CEL': 1726,
#   'VPH_INTER': 27,
#   'VPH_STVP': 572,
#   'VPH_SPMVPI': 0,
#   'VPH_CVJ': 1},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 93,
#   'NOM_MUN': 'Tenejapa',
#   'POBTOT': 48162,
#   'POBFEM': 24852,
#   'POBMAS': 23306,
#   'PEA': 14848,
#   'TVIVPARHAB': 9205,
#   'VPH_RADIO': 4417,
#   'VPH_TV': 4988,
#   'VPH_PC': 72,
#   'VPH_TELEF': 828,
#   'VPH_CEL': 2882,
#   'VPH_INTER': 107,
#   'VPH_STVP': 658,
#   'VPH_SPMVPI': 5,
#   'VPH_CVJ': 4},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 80,
#   'NOM_MUN': 'Siltepec',
#   'POBTOT': 25937,
#   'POBFEM': 12904,
#   'POBMAS': 13021,
#   'PEA': 9295,
#   'TVIVPARHAB': 5203,
#   'VPH_RADIO': 3383,
#   'VPH_TV': 3773,
#   'VPH_PC': 243,
#   'VPH_TELEF': 303,
#   'VPH_CEL': 3691,
#   'VPH_INTER': 325,
#   'VPH_STVP': 1892,
#   'VPH_SPMVPI': 11,
#   'VPH_CVJ': 16},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 94,
#   'NOM_MUN': 'Teopisca',
#   'POBTOT': 49499,
#   'POBFEM': 25502,
#   'POBMAS': 23883,
#   'PEA': 22497,
#   'TVIVPARHAB': 11150,
#   'VPH_RADIO': 6881,
#   'VPH_TV': 7990,
#   'VPH_PC': 689,
#   'VPH_TELEF': 379,
#   'VPH_CEL': 8595,
#   'VPH_INTER': 613,
#   'VPH_STVP': 3712,
#   'VPH_SPMVPI': 77,
#   'VPH_CVJ': 64},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 110,
#   'NOM_MUN': 'San Lucas',
#   'POBTOT': 7526,
#   'POBFEM': 3728,
#   'POBMAS': 3788,
#   'PEA': 3049,
#   'TVIVPARHAB': 1827,
#   'VPH_RADIO': 1048,
#   'VPH_TV': 1473,
#   'VPH_PC': 80,
#   'VPH_TELEF': 56,
#   'VPH_CEL': 1338,
#   'VPH_INTER': 52,
#   'VPH_STVP': 791,
#   'VPH_SPMVPI': 2,
#   'VPH_CVJ': 7},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 97,
#   'NOM_MUN': 'Tonalá',
#   'POBTOT': 91913,
#   'POBFEM': 45863,
#   'POBMAS': 44201,
#   'PEA': 44041,
#   'TVIVPARHAB': 25094,
#   'VPH_RADIO': 15612,
#   'VPH_TV': 21963,
#   'VPH_PC': 3844,
#   'VPH_TELEF': 3178,
#   'VPH_CEL': 20887,
#   'VPH_INTER': 6565,
#   'VPH_STVP': 11801,
#   'VPH_SPMVPI': 823,
#   'VPH_CVJ': 392},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 64,
#   'NOM_MUN': 'Oxchuc',
#   'POBTOT': 54932,
#   'POBFEM': 27397,
#   'POBMAS': 27497,
#   'PEA': 13954,
#   'TVIVPARHAB': 10096,
#   'VPH_RADIO': 3326,
#   'VPH_TV': 2746,
#   'VPH_PC': 206,
#   'VPH_TELEF': 75,
#   'VPH_CEL': 2858,
#   'VPH_INTER': 174,
#   'VPH_STVP': 289,
#   'VPH_SPMVPI': 11,
#   'VPH_CVJ': 4},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 125,
#   'NOM_MUN': 'Honduras de la Sierra',
#   'POBTOT': 11650,
#   'POBFEM': 5728,
#   'POBMAS': 5864,
#   'PEA': 5283,
#   'TVIVPARHAB': 2332,
#   'VPH_RADIO': 1017,
#   'VPH_TV': 1483,
#   'VPH_PC': 58,
#   'VPH_TELEF': 139,
#   'VPH_CEL': 928,
#   'VPH_INTER': 121,
#   'VPH_STVP': 563,
#   'VPH_SPMVPI': 12,
#   'VPH_CVJ': 10},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 124,
#   'NOM_MUN': 'Mezcalapa',
#   'POBTOT': 23847,
#   'POBFEM': 11907,
#   'POBMAS': 11425,
#   'PEA': 9826,
#   'TVIVPARHAB': 5702,
#   'VPH_RADIO': 1240,
#   'VPH_TV': 3991,
#   'VPH_PC': 520,
#   'VPH_TELEF': 257,
#   'VPH_CEL': 3904,
#   'VPH_INTER': 628,
#   'VPH_STVP': 2756,
#   'VPH_SPMVPI': 83,
#   'VPH_CVJ': 70},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 123,
#   'NOM_MUN': 'Emiliano Zapata',
#   'POBTOT': 10783,
#   'POBFEM': 5315,
#   'POBMAS': 5256,
#   'PEA': 4799,
#   'TVIVPARHAB': 2769,
#   'VPH_RADIO': 1702,
#   'VPH_TV': 2436,
#   'VPH_PC': 327,
#   'VPH_TELEF': 126,
#   'VPH_CEL': 2227,
#   'VPH_INTER': 514,
#   'VPH_STVP': 1037,
#   'VPH_SPMVPI': 36,
#   'VPH_CVJ': 22},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 122,
#   'NOM_MUN': 'El Parral',
#   'POBTOT': 15587,
#   'POBFEM': 7863,
#   'POBMAS': 7421,
#   'PEA': 6636,
#   'TVIVPARHAB': 4188,
#   'VPH_RADIO': 3158,
#   'VPH_TV': 3753,
#   'VPH_PC': 430,
#   'VPH_TELEF': 206,
#   'VPH_CEL': 3215,
#   'VPH_INTER': 297,
#   'VPH_STVP': 1463,
#   'VPH_SPMVPI': 25,
#   'VPH_CVJ': 50},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 121,
#   'NOM_MUN': 'Rincón Chamula San Pedro',
#   'POBTOT': 8718,
#   'POBFEM': 4691,
#   'POBMAS': 4027,
#   'PEA': 2900,
#   'TVIVPARHAB': 1847,
#   'VPH_RADIO': 311,
#   'VPH_TV': 1176,
#   'VPH_PC': 20,
#   'VPH_TELEF': 6,
#   'VPH_CEL': 1152,
#   'VPH_INTER': 46,
#   'VPH_STVP': 49,
#   'VPH_SPMVPI': 2,
#   'VPH_CVJ': 2},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 120,
#   'NOM_MUN': 'Capitán Luis Ángel Vidal',
#   'POBTOT': 4315,
#   'POBFEM': 2000,
#   'POBMAS': 2219,
#   'PEA': 1474,
#   'TVIVPARHAB': 782,
#   'VPH_RADIO': 465,
#   'VPH_TV': 450,
#   'VPH_PC': 16,
#   'VPH_TELEF': 9,
#   'VPH_CEL': 341,
#   'VPH_INTER': 72,
#   'VPH_STVP': 249,
#   'VPH_SPMVPI': 0,
#   'VPH_CVJ': 0},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 119,
#   'NOM_MUN': 'Santiago el Pinar',
#   'POBTOT': 4959,
#   'POBFEM': 2504,
#   'POBMAS': 2445,
#   'PEA': 1323,
#   'TVIVPARHAB': 910,
#   'VPH_RADIO': 212,
#   'VPH_TV': 450,
#   'VPH_PC': 6,
#   'VPH_TELEF': 7,
#   'VPH_CEL': 362,
#   'VPH_INTER': 7,
#   'VPH_STVP': 93,
#   'VPH_SPMVPI': 2,
#   'VPH_CVJ': 0},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 118,
#   'NOM_MUN': 'San Andrés Duraznal',
#   'POBTOT': 6047,
#   'POBFEM': 3112,
#   'POBMAS': 2922,
#   'PEA': 1684,
#   'TVIVPARHAB': 1309,
#   'VPH_RADIO': 210,
#   'VPH_TV': 484,
#   'VPH_PC': 11,
#   'VPH_TELEF': 6,
#   'VPH_CEL': 413,
#   'VPH_INTER': 23,
#   'VPH_STVP': 42,
#   'VPH_SPMVPI': 1,
#   'VPH_CVJ': 0},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 117,
#   'NOM_MUN': 'Montecristo de Guerrero',
#   'POBTOT': 8412,
#   'POBFEM': 4151,
#   'POBMAS': 4161,
#   'PEA': 3104,
#   'TVIVPARHAB': 1807,
#   'VPH_RADIO': 1095,
#   'VPH_TV': 1444,
#   'VPH_PC': 63,
#   'VPH_TELEF': 29,
#   'VPH_CEL': 1249,
#   'VPH_INTER': 310,
#   'VPH_STVP': 628,
#   'VPH_SPMVPI': 1,
#   'VPH_CVJ': 9},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 116,
#   'NOM_MUN': 'Marqués de Comillas',
#   'POBTOT': 12892,
#   'POBFEM': 6394,
#   'POBMAS': 6497,
#   'PEA': 4834,
#   'TVIVPARHAB': 2896,
#   'VPH_RADIO': 808,
#   'VPH_TV': 1730,
#   'VPH_PC': 126,
#   'VPH_TELEF': 53,
#   'VPH_CEL': 1466,
#   'VPH_INTER': 103,
#   'VPH_STVP': 1348,
#   'VPH_SPMVPI': 12,
#   'VPH_CVJ': 7},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 115,
#   'NOM_MUN': 'Maravilla Tenejapa',
#   'POBTOT': 14714,
#   'POBFEM': 7380,
#   'POBMAS': 7328,
#   'PEA': 4315,
#   'TVIVPARHAB': 2950,
#   'VPH_RADIO': 816,
#   'VPH_TV': 1483,
#   'VPH_PC': 83,
#   'VPH_TELEF': 50,
#   'VPH_CEL': 972,
#   'VPH_INTER': 346,
#   'VPH_STVP': 901,
#   'VPH_SPMVPI': 6,
#   'VPH_CVJ': 3},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 114,
#   'NOM_MUN': 'Benemérito de las Américas',
#   'POBTOT': 23603,
#   'POBFEM': 11743,
#   'POBMAS': 11759,
#   'PEA': 10229,
#   'TVIVPARHAB': 5451,
#   'VPH_RADIO': 1688,
#   'VPH_TV': 3663,
#   'VPH_PC': 430,
#   'VPH_TELEF': 101,
#   'VPH_CEL': 3674,
#   'VPH_INTER': 355,
#   'VPH_STVP': 2999,
#   'VPH_SPMVPI': 13,
#   'VPH_CVJ': 21},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 96,
#   'NOM_MUN': 'Tila',
#   'POBTOT': 83505,
#   'POBFEM': 41790,
#   'POBMAS': 41682,
#   'PEA': 37988,
#   'TVIVPARHAB': 17860,
#   'VPH_RADIO': 6149,
#   'VPH_TV': 8063,
#   'VPH_PC': 404,
#   'VPH_TELEF': 119,
#   'VPH_CEL': 4607,
#   'VPH_INTER': 284,
#   'VPH_STVP': 3391,
#   'VPH_SPMVPI': 12,
#   'VPH_CVJ': 17},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 113,
#   'NOM_MUN': 'Aldama',
#   'POBTOT': 8480,
#   'POBFEM': 4429,
#   'POBMAS': 4037,
#   'PEA': 2364,
#   'TVIVPARHAB': 1651,
#   'VPH_RADIO': 544,
#   'VPH_TV': 727,
#   'VPH_PC': 11,
#   'VPH_TELEF': 47,
#   'VPH_CEL': 507,
#   'VPH_INTER': 17,
#   'VPH_STVP': 4,
#   'VPH_SPMVPI': 0,
#   'VPH_CVJ': 1},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 111,
#   'NOM_MUN': 'Zinacantán',
#   'POBTOT': 45373,
#   'POBFEM': 24258,
#   'POBMAS': 21115,
#   'PEA': 14989,
#   'TVIVPARHAB': 9128,
#   'VPH_RADIO': 4538,
#   'VPH_TV': 6314,
#   'VPH_PC': 111,
#   'VPH_TELEF': 168,
#   'VPH_CEL': 4838,
#   'VPH_INTER': 480,
#   'VPH_STVP': 359,
#   'VPH_SPMVPI': 9,
#   'VPH_CVJ': 9},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 109,
#   'NOM_MUN': 'Yajalón',
#   'POBTOT': 40285,
#   'POBFEM': 20588,
#   'POBMAS': 19473,
#   'PEA': 19014,
#   'TVIVPARHAB': 8704,
#   'VPH_RADIO': 4659,
#   'VPH_TV': 5812,
#   'VPH_PC': 1107,
#   'VPH_TELEF': 678,
#   'VPH_CEL': 5606,
#   'VPH_INTER': 1169,
#   'VPH_STVP': 3158,
#   'VPH_SPMVPI': 143,
#   'VPH_CVJ': 76},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 108,
#   'NOM_MUN': 'Villaflores',
#   'POBTOT': 109536,
#   'POBFEM': 53840,
#   'POBMAS': 51718,
#   'PEA': 51081,
#   'TVIVPARHAB': 28211,
#   'VPH_RADIO': 17526,
#   'VPH_TV': 24947,
#   'VPH_PC': 4308,
#   'VPH_TELEF': 4055,
#   'VPH_CEL': 22721,
#   'VPH_INTER': 6025,
#   'VPH_STVP': 15453,
#   'VPH_SPMVPI': 900,
#   'VPH_CVJ': 491},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 107,
#   'NOM_MUN': 'Villa Corzo',
#   'POBTOT': 65643,
#   'POBFEM': 31068,
#   'POBMAS': 29857,
#   'PEA': 28562,
#   'TVIVPARHAB': 15638,
#   'VPH_RADIO': 9438,
#   'VPH_TV': 13208,
#   'VPH_PC': 1916,
#   'VPH_TELEF': 1930,
#   'VPH_CEL': 11658,
#   'VPH_INTER': 3586,
#   'VPH_STVP': 7487,
#   'VPH_SPMVPI': 346,
#   'VPH_CVJ': 203},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 106,
#   'NOM_MUN': 'Venustiano Carranza',
#   'POBTOT': 67288,
#   'POBFEM': 33364,
#   'POBMAS': 33071,
#   'PEA': 32767,
#   'TVIVPARHAB': 17677,
#   'VPH_RADIO': 9897,
#   'VPH_TV': 14048,
#   'VPH_PC': 1429,
#   'VPH_TELEF': 852,
#   'VPH_CEL': 11575,
#   'VPH_INTER': 1045,
#   'VPH_STVP': 2954,
#   'VPH_SPMVPI': 152,
#   'VPH_CVJ': 126},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 105,
#   'NOM_MUN': 'Unión Juárez',
#   'POBTOT': 16008,
#   'POBFEM': 8138,
#   'POBMAS': 7822,
#   'PEA': 6290,
#   'TVIVPARHAB': 3923,
#   'VPH_RADIO': 2721,
#   'VPH_TV': 3405,
#   'VPH_PC': 432,
#   'VPH_TELEF': 251,
#   'VPH_CEL': 3225,
#   'VPH_INTER': 770,
#   'VPH_STVP': 1085,
#   'VPH_SPMVPI': 80,
#   'VPH_CVJ': 47},
#  {'ENTIDAD': 7,
#   'NOM_ENT': 'Chiapas',
#   'MUN': 104,
#   'NOM_MUN': 'Tzimol',
#   'POBTOT': 16560,
#   'POBFEM': 8329,
#   'POBMAS': 7973,
#   'PEA': 7546,
#   'TVIVPARHAB': 4600,
#   'VPH_RADIO': 3015,
#   'VPH_TV': 3852,
# ...
#  {'ENTIDAD': 18,
#   'NOM_ENT': 'Nayarit',
#   'MUN': 2,
#   'NOM_MUN': 'Ahuacatlán',
#   'POBTOT': 15393,
#   'POBFEM': 7684,
#   'POBMAS': 7544,
#   'PEA': 7272,
#   'TVIVPARHAB': 4786,
#   'VPH_RADIO': 2623,
#   'VPH_TV': 4451,
#   'VPH_PC': 1358,
#   'VPH_TELEF': 1446,
#   'VPH_CEL': 4134,
#   'VPH_INTER': 1564,
#   'VPH_STVP': 3228,
#   'VPH_SPMVPI': 321,
#   'VPH_CVJ': 296},
#  {'ENTIDAD': 18,
#   'NOM_ENT': 'Nayarit',
#   'MUN': 1,
#   'NOM_MUN': 'Acaponeta',
#   'POBTOT': 37232,
#   'POBFEM': 18519,
#   'POBMAS': 18478,
#   'PEA': 17294,
#   'TVIVPARHAB': 10785,
#   'VPH_RADIO': 6181,
#   'VPH_TV': 9409,
#   'VPH_PC': 2385,
#   'VPH_TELEF': 2946,
#   'VPH_CEL': 9072,
#   'VPH_INTER': 3358,
#   'VPH_STVP': 5017,
#   'VPH_SPMVPI': 750,
#   'VPH_CVJ': 406},
#  {'ENTIDAD': 18,
#   'NOM_ENT': 'Nayarit',
#   'MUN': 9,
#   'NOM_MUN': 'Del Nayar',
#   'POBTOT': 47550,
#   'POBFEM': 23312,
#   'POBMAS': 22698,
#   'PEA': 10146,
#   'TVIVPARHAB': 8641,
#   'VPH_RADIO': 3444,
#   'VPH_TV': 3013,
#   'VPH_PC': 350,
#   'VPH_TELEF': 281,
#   'VPH_CEL': 3458,
#   'VPH_INTER': 257,
#   'VPH_STVP': 1545,
#   'VPH_SPMVPI': 22,
#   'VPH_CVJ': 21},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 36,
#   'NOM_MUN': 'Mier y Noriega',
#   'POBTOT': 7652,
#   'POBFEM': 3849,
#   'POBMAS': 3784,
#   'PEA': 2347,
#   'TVIVPARHAB': 1872,
#   'VPH_RADIO': 838,
#   'VPH_TV': 1621,
#   'VPH_PC': 99,
#   'VPH_TELEF': 172,
#   'VPH_CEL': 1282,
#   'VPH_INTER': 183,
#   'VPH_STVP': 1247,
#   'VPH_SPMVPI': 22,
#   'VPH_CVJ': 19},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 35,
#   'NOM_MUN': 'Melchor Ocampo',
#   'POBTOT': 1483,
#   'POBFEM': 709,
#   'POBMAS': 757,
#   'PEA': 570,
#   'TVIVPARHAB': 455,
#   'VPH_RADIO': 371,
#   'VPH_TV': 437,
#   'VPH_PC': 125,
#   'VPH_TELEF': 141,
#   'VPH_CEL': 416,
#   'VPH_INTER': 140,
#   'VPH_STVP': 157,
#   'VPH_SPMVPI': 31,
#   'VPH_CVJ': 31},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 34,
#   'NOM_MUN': 'Marín',
#   'POBTOT': 5119,
#   'POBFEM': 2455,
#   'POBMAS': 2607,
#   'PEA': 2205,
#   'TVIVPARHAB': 1422,
#   'VPH_RADIO': 988,
#   'VPH_TV': 1375,
#   'VPH_PC': 474,
#   'VPH_TELEF': 396,
#   'VPH_CEL': 1362,
#   'VPH_INTER': 559,
#   'VPH_STVP': 529,
#   'VPH_SPMVPI': 184,
#   'VPH_CVJ': 135},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 33,
#   'NOM_MUN': 'Linares',
#   'POBTOT': 84662,
#   'POBFEM': 42389,
#   'POBMAS': 41393,
#   'PEA': 38244,
#   'TVIVPARHAB': 24186,
#   'VPH_RADIO': 15272,
#   'VPH_TV': 22685,
#   'VPH_PC': 8563,
#   'VPH_TELEF': 9152,
#   'VPH_CEL': 22043,
#   'VPH_INTER': 13046,
#   'VPH_STVP': 12447,
#   'VPH_SPMVPI': 3922,
#   'VPH_CVJ': 2220},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 28,
#   'NOM_MUN': 'Higueras',
#   'POBTOT': 1386,
#   'POBFEM': 635,
#   'POBMAS': 668,
#   'PEA': 516,
#   'TVIVPARHAB': 391,
#   'VPH_RADIO': 280,
#   'VPH_TV': 364,
#   'VPH_PC': 107,
#   'VPH_TELEF': 96,
#   'VPH_CEL': 359,
#   'VPH_INTER': 114,
#   'VPH_STVP': 210,
#   'VPH_SPMVPI': 32,
#   'VPH_CVJ': 25},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 31,
#   'NOM_MUN': 'Juárez',
#   'POBTOT': 471523,
#   'POBFEM': 233718,
#   'POBMAS': 237604,
#   'PEA': 231462,
#   'TVIVPARHAB': 134366,
#   'VPH_RADIO': 93966,
#   'VPH_TV': 127390,
#   'VPH_PC': 47143,
#   'VPH_TELEF': 53541,
#   'VPH_CEL': 128118,
#   'VPH_INTER': 82212,
#   'VPH_STVP': 55617,
#   'VPH_SPMVPI': 28195,
#   'VPH_CVJ': 19332},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 30,
#   'NOM_MUN': 'Iturbide',
#   'POBTOT': 3298,
#   'POBFEM': 1538,
#   'POBMAS': 1666,
#   'PEA': 1156,
#   'TVIVPARHAB': 966,
#   'VPH_RADIO': 494,
#   'VPH_TV': 809,
#   'VPH_PC': 112,
#   'VPH_TELEF': 142,
#   'VPH_CEL': 618,
#   'VPH_INTER': 118,
#   'VPH_STVP': 687,
#   'VPH_SPMVPI': 15,
#   'VPH_CVJ': 17},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 29,
#   'NOM_MUN': 'Hualahuises',
#   'POBTOT': 7026,
#   'POBFEM': 3483,
#   'POBMAS': 3403,
#   'PEA': 2671,
#   'TVIVPARHAB': 2115,
#   'VPH_RADIO': 1535,
#   'VPH_TV': 1992,
#   'VPH_PC': 692,
#   'VPH_TELEF': 804,
#   'VPH_CEL': 1893,
#   'VPH_INTER': 1041,
#   'VPH_STVP': 1076,
#   'VPH_SPMVPI': 249,
#   'VPH_CVJ': 212},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 37,
#   'NOM_MUN': 'Mina',
#   'POBTOT': 6048,
#   'POBFEM': 2955,
#   'POBMAS': 2996,
#   'PEA': 2444,
#   'TVIVPARHAB': 1661,
#   'VPH_RADIO': 1017,
#   'VPH_TV': 1545,
#   'VPH_PC': 446,
#   'VPH_TELEF': 244,
#   'VPH_CEL': 1467,
#   'VPH_INTER': 496,
#   'VPH_STVP': 1268,
#   'VPH_SPMVPI': 148,
#   'VPH_CVJ': 127},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 32,
#   'NOM_MUN': 'Lampazos de Naranjo',
#   'POBTOT': 5351,
#   'POBFEM': 2669,
#   'POBMAS': 2610,
#   'PEA': 2216,
#   'TVIVPARHAB': 1631,
#   'VPH_RADIO': 1189,
#   'VPH_TV': 1555,
#   'VPH_PC': 322,
#   'VPH_TELEF': 493,
#   'VPH_CEL': 1477,
#   'VPH_INTER': 501,
#   'VPH_STVP': 1146,
#   'VPH_SPMVPI': 98,
#   'VPH_CVJ': 74},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 39,
#   'NOM_MUN': 'Monterrey',
#   'POBTOT': 1142994,
#   'POBFEM': 578183,
#   'POBMAS': 564796,
#   'PEA': 575168,
#   'TVIVPARHAB': 328903,
#   'VPH_RADIO': 227625,
#   'VPH_TV': 315450,
#   'VPH_PC': 189682,
#   'VPH_TELEF': 227465,
#   'VPH_CEL': 298534,
#   'VPH_INTER': 255220,
#   'VPH_STVP': 162826,
#   'VPH_SPMVPI': 122500,
#   'VPH_CVJ': 70702},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 44,
#   'NOM_MUN': 'Sabinas Hidalgo',
#   'POBTOT': 34702,
#   'POBFEM': 17600,
#   'POBMAS': 16930,
#   'PEA': 16303,
#   'TVIVPARHAB': 10728,
#   'VPH_RADIO': 7223,
#   'VPH_TV': 10248,
#   'VPH_PC': 4411,
#   'VPH_TELEF': 5427,
#   'VPH_CEL': 9644,
#   'VPH_INTER': 6091,
#   'VPH_STVP': 6405,
#   'VPH_SPMVPI': 1970,
#   'VPH_CVJ': 1449},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 41,
#   'NOM_MUN': 'Pesquería',
#   'POBTOT': 147624,
#   'POBFEM': 71506,
#   'POBMAS': 75837,
#   'PEA': 74873,
#   'TVIVPARHAB': 43583,
#   'VPH_RADIO': 31056,
#   'VPH_TV': 39523,
#   'VPH_PC': 10170,
#   'VPH_TELEF': 11462,
#   'VPH_CEL': 41540,
#   'VPH_INTER': 21377,
#   'VPH_STVP': 15435,
#   'VPH_SPMVPI': 6265,
#   'VPH_CVJ': 3928},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 42,
#   'NOM_MUN': 'Los Ramones',
#   'POBTOT': 5389,
#   'POBFEM': 2513,
#   'POBMAS': 2617,
#   'PEA': 2084,
#   'TVIVPARHAB': 1766,
#   'VPH_RADIO': 1042,
#   'VPH_TV': 1689,
#   'VPH_PC': 298,
#   'VPH_TELEF': 298,
#   'VPH_CEL': 1581,
#   'VPH_INTER': 664,
#   'VPH_STVP': 645,
#   'VPH_SPMVPI': 66,
#   'VPH_CVJ': 76},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 43,
#   'NOM_MUN': 'Rayones',
#   'POBTOT': 2377,
#   'POBFEM': 1075,
#   'POBMAS': 1142,
#   'PEA': 845,
#   'TVIVPARHAB': 714,
#   'VPH_RADIO': 374,
#   'VPH_TV': 653,
#   'VPH_PC': 67,
#   'VPH_TELEF': 87,
#   'VPH_CEL': 450,
#   'VPH_INTER': 32,
#   'VPH_STVP': 565,
#   'VPH_SPMVPI': 8,
#   'VPH_CVJ': 18},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 27,
#   'NOM_MUN': 'Los Herreras',
#   'POBTOT': 1959,
#   'POBFEM': 949,
#   'POBMAS': 960,
#   'PEA': 644,
#   'TVIVPARHAB': 707,
#   'VPH_RADIO': 403,
#   'VPH_TV': 664,
#   'VPH_PC': 122,
#   'VPH_TELEF': 199,
#   'VPH_CEL': 609,
#   'VPH_INTER': 271,
#   'VPH_STVP': 266,
#   'VPH_SPMVPI': 24,
#   'VPH_CVJ': 17},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 45,
#   'NOM_MUN': 'Salinas Victoria',
#   'POBTOT': 86766,
#   'POBFEM': 42471,
#   'POBMAS': 43924,
#   'PEA': 42875,
#   'TVIVPARHAB': 25290,
#   'VPH_RADIO': 17064,
#   'VPH_TV': 23590,
#   'VPH_PC': 6329,
#   'VPH_TELEF': 6620,
#   'VPH_CEL': 23769,
#   'VPH_INTER': 12022,
#   'VPH_STVP': 8274,
#   'VPH_SPMVPI': 3204,
#   'VPH_CVJ': 2208},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 46,
#   'NOM_MUN': 'San Nicolás de los Garza',
#   'POBTOT': 412199,
#   'POBFEM': 209241,
#   'POBMAS': 202958,
#   'PEA': 204861,
#   'TVIVPARHAB': 121777,
#   'VPH_RADIO': 85602,
#   'VPH_TV': 119132,
#   'VPH_PC': 75260,
#   'VPH_TELEF': 93035,
#   'VPH_CEL': 112568,
#   'VPH_INTER': 101205,
#   'VPH_STVP': 66201,
#   'VPH_SPMVPI': 47735,
#   'VPH_CVJ': 27587},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 47,
#   'NOM_MUN': 'Hidalgo',
#   'POBTOT': 16082,
#   'POBFEM': 7997,
#   'POBMAS': 8074,
#   'PEA': 7461,
#   'TVIVPARHAB': 4574,
#   'VPH_RADIO': 2939,
#   'VPH_TV': 4372,
#   'VPH_PC': 1683,
#   'VPH_TELEF': 1519,
#   'VPH_CEL': 4136,
#   'VPH_INTER': 2258,
#   'VPH_STVP': 3041,
#   'VPH_SPMVPI': 631,
#   'VPH_CVJ': 424},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 48,
#   'NOM_MUN': 'Santa Catarina',
#   'POBTOT': 306319,
#   'POBFEM': 153686,
#   'POBMAS': 152562,
#   'PEA': 155489,
#   'TVIVPARHAB': 82874,
#   'VPH_RADIO': 55539,
#   'VPH_TV': 79616,
#   'VPH_PC': 43847,
#   'VPH_TELEF': 52564,
#   'VPH_CEL': 76581,
#   'VPH_INTER': 63082,
#   'VPH_STVP': 36838,
#   'VPH_SPMVPI': 26752,
#   'VPH_CVJ': 17991},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 49,
#   'NOM_MUN': 'Santiago',
#   'POBTOT': 46784,
#   'POBFEM': 23218,
#   'POBMAS': 23322,
#   'PEA': 22000,
#   'TVIVPARHAB': 14344,
#   'VPH_RADIO': 8935,
#   'VPH_TV': 13610,
#   'VPH_PC': 6773,
#   'VPH_TELEF': 7643,
#   'VPH_CEL': 12830,
#   'VPH_INTER': 9134,
#   'VPH_STVP': 7812,
#   'VPH_SPMVPI': 4001,
#   'VPH_CVJ': 2454},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 50,
#   'NOM_MUN': 'Vallecillo',
#   'POBTOT': 1552,
#   'POBFEM': 675,
#   'POBMAS': 746,
#   'PEA': 598,
#   'TVIVPARHAB': 518,
#   'VPH_RADIO': 338,
#   'VPH_TV': 478,
#   'VPH_PC': 80,
#   'VPH_TELEF': 92,
#   'VPH_CEL': 431,
#   'VPH_INTER': 73,
#   'VPH_STVP': 373,
#   'VPH_SPMVPI': 12,
#   'VPH_CVJ': 14},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 51,
#   'NOM_MUN': 'Villaldama',
#   'POBTOT': 3573,
#   'POBFEM': 1763,
#   'POBMAS': 1757,
#   'PEA': 1399,
#   'TVIVPARHAB': 1245,
#   'VPH_RADIO': 712,
#   'VPH_TV': 1166,
#   'VPH_PC': 261,
#   'VPH_TELEF': 492,
#   'VPH_CEL': 986,
#   'VPH_INTER': 377,
#   'VPH_STVP': 656,
#   'VPH_SPMVPI': 104,
#   'VPH_CVJ': 91},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 40,
#   'NOM_MUN': 'Parás',
#   'POBTOT': 906,
#   'POBFEM': 429,
#   'POBMAS': 430,
#   'PEA': 312,
#   'TVIVPARHAB': 312,
#   'VPH_RADIO': 153,
#   'VPH_TV': 288,
#   'VPH_PC': 86,
#   'VPH_TELEF': 142,
#   'VPH_CEL': 270,
#   'VPH_INTER': 121,
#   'VPH_STVP': 194,
#   'VPH_SPMVPI': 19,
#   'VPH_CVJ': 11},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 26,
#   'NOM_MUN': 'Guadalupe',
#   'POBTOT': 643143,
#   'POBFEM': 324145,
#   'POBMAS': 318985,
#   'PEA': 321847,
#   'TVIVPARHAB': 182496,
#   'VPH_RADIO': 125398,
#   'VPH_TV': 177416,
#   'VPH_PC': 99958,
#   'VPH_TELEF': 124539,
#   'VPH_CEL': 168365,
#   'VPH_INTER': 141949,
#   'VPH_STVP': 92119,
#   'VPH_SPMVPI': 61195,
#   'VPH_CVJ': 37150},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 38,
#   'NOM_MUN': 'Montemorelos',
#   'POBTOT': 67428,
#   'POBFEM': 33492,
#   'POBMAS': 33131,
#   'PEA': 32340,
#   'TVIVPARHAB': 20575,
#   'VPH_RADIO': 12840,
#   'VPH_TV': 19177,
#   'VPH_PC': 8008,
#   'VPH_TELEF': 8143,
#   'VPH_CEL': 18784,
#   'VPH_INTER': 11542,
#   'VPH_STVP': 10363,
#   'VPH_SPMVPI': 3390,
#   'VPH_CVJ': 1730},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 24,
#   'NOM_MUN': 'General Zaragoza',
#   'POBTOT': 6282,
#   'POBFEM': 2960,
#   'POBMAS': 3106,
#   'PEA': 2188,
#   'TVIVPARHAB': 1590,
#   'VPH_RADIO': 644,
#   'VPH_TV': 1161,
#   'VPH_PC': 195,
#   'VPH_TELEF': 139,
#   'VPH_CEL': 1248,
#   'VPH_INTER': 127,
#   'VPH_STVP': 853,
#   'VPH_SPMVPI': 13,
#   'VPH_CVJ': 21},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 25,
#   'NOM_MUN': 'General Zuazua',
#   'POBTOT': 102149,
#   'POBFEM': 50248,
#   'POBMAS': 51765,
#   'PEA': 50196,
#   'TVIVPARHAB': 29586,
#   'VPH_RADIO': 21054,
#   'VPH_TV': 27465,
#   'VPH_PC': 8765,
#   'VPH_TELEF': 10563,
#   'VPH_CEL': 28269,
#   'VPH_INTER': 17827,
#   'VPH_STVP': 11948,
#   'VPH_SPMVPI': 5277,
#   'VPH_CVJ': 3411},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 1,
#   'NOM_MUN': 'Abasolo',
#   'POBTOT': 2974,
#   'POBFEM': 1514,
#   'POBMAS': 1416,
#   'PEA': 1111,
#   'TVIVPARHAB': 791,
#   'VPH_RADIO': 580,
#   'VPH_TV': 758,
#   'VPH_PC': 238,
#   'VPH_TELEF': 100,
#   'VPH_CEL': 736,
#   'VPH_INTER': 347,
#   'VPH_STVP': 356,
#   'VPH_SPMVPI': 125,
#   'VPH_CVJ': 108},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 2,
#   'NOM_MUN': 'Agualeguas',
#   'POBTOT': 3382,
#   'POBFEM': 1647,
#   'POBMAS': 1617,
#   'PEA': 1266,
#   'TVIVPARHAB': 1224,
#   'VPH_RADIO': 641,
#   'VPH_TV': 1158,
#   'VPH_PC': 264,
#   'VPH_TELEF': 363,
#   'VPH_CEL': 1050,
#   'VPH_INTER': 451,
#   'VPH_STVP': 786,
#   'VPH_SPMVPI': 78,
#   'VPH_CVJ': 50},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 3,
#   'NOM_MUN': 'Los Aldamas',
#   'POBTOT': 1407,
#   'POBFEM': 702,
#   'POBMAS': 690,
#   'PEA': 522,
#   'TVIVPARHAB': 533,
#   'VPH_RADIO': 305,
#   'VPH_TV': 496,
#   'VPH_PC': 105,
#   'VPH_TELEF': 147,
#   'VPH_CEL': 483,
#   'VPH_INTER': 120,
#   'VPH_STVP': 178,
#   'VPH_SPMVPI': 28,
#   'VPH_CVJ': 25},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 4,
#   'NOM_MUN': 'Allende',
#   'POBTOT': 35289,
#   'POBFEM': 17428,
#   'POBMAS': 17794,
#   'PEA': 16992,
#   'TVIVPARHAB': 10685,
#   'VPH_RADIO': 6341,
#   'VPH_TV': 10197,
#   'VPH_PC': 4616,
#   'VPH_TELEF': 4652,
#   'VPH_CEL': 9845,
#   'VPH_INTER': 6414,
#   'VPH_STVP': 6792,
#   'VPH_SPMVPI': 2407,
#   'VPH_CVJ': 1441},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 5,
#   'NOM_MUN': 'Anáhuac',
#   'POBTOT': 18030,
#   'POBFEM': 8993,
#   'POBMAS': 8562,
#   'PEA': 7554,
#   'TVIVPARHAB': 5266,
#   'VPH_RADIO': 3498,
#   'VPH_TV': 4898,
#   'VPH_PC': 1324,
#   'VPH_TELEF': 1846,
#   'VPH_CEL': 4777,
#   'VPH_INTER': 2113,
#   'VPH_STVP': 3182,
#   'VPH_SPMVPI': 489,
#   'VPH_CVJ': 368},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 7,
#   'NOM_MUN': 'Aramberri',
#   'POBTOT': 14987,
#   'POBFEM': 7220,
#   'POBMAS': 7507,
#   'PEA': 6067,
#   'TVIVPARHAB': 4194,
#   'VPH_RADIO': 1921,
#   'VPH_TV': 3527,
#   'VPH_PC': 512,
#   'VPH_TELEF': 573,
#   'VPH_CEL': 3225,
#   'VPH_INTER': 587,
#   'VPH_STVP': 2746,
#   'VPH_SPMVPI': 85,
#   'VPH_CVJ': 85},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 8,
#   'NOM_MUN': 'Bustamante',
#   'POBTOT': 3658,
#   'POBFEM': 1798,
#   'POBMAS': 1759,
#   'PEA': 1345,
#   'TVIVPARHAB': 1134,
#   'VPH_RADIO': 654,
#   'VPH_TV': 1034,
#   'VPH_PC': 298,
#   'VPH_TELEF': 363,
#   'VPH_CEL': 969,
#   'VPH_INTER': 424,
#   'VPH_STVP': 797,
#   'VPH_SPMVPI': 84,
#   'VPH_CVJ': 82},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 9,
#   'NOM_MUN': 'Cadereyta Jiménez',
#   'POBTOT': 122337,
#   'POBFEM': 59720,
#   'POBMAS': 60209,
#   'PEA': 57337,
#   'TVIVPARHAB': 37178,
#   'VPH_RADIO': 23478,
#   'VPH_TV': 34995,
#   'VPH_PC': 11642,
#   'VPH_TELEF': 13432,
#   'VPH_CEL': 34455,
#   'VPH_INTER': 20102,
#   'VPH_STVP': 16270,
#   'VPH_SPMVPI': 7026,
#   'VPH_CVJ': 4374},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 10,
#   'NOM_MUN': 'El Carmen',
#   'POBTOT': 104478,
#   'POBFEM': 51574,
#   'POBMAS': 52856,
#   'PEA': 48249,
#   'TVIVPARHAB': 30024,
#   'VPH_RADIO': 21164,
#   'VPH_TV': 27726,
#   'VPH_PC': 7316,
#   'VPH_TELEF': 8387,
#   'VPH_CEL': 28528,
#   'VPH_INTER': 15418,
#   'VPH_STVP': 12393,
#   'VPH_SPMVPI': 4118,
#   'VPH_CVJ': 2989},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 11,
#   'NOM_MUN': 'Cerralvo',
#   'POBTOT': 7340,
#   'POBFEM': 3563,
#   'POBMAS': 3607,
#   'PEA': 3095,
#   'TVIVPARHAB': 2387,
#   'VPH_RADIO': 1453,
#   'VPH_TV': 2239,
#   'VPH_PC': 725,
#   'VPH_TELEF': 898,
#   'VPH_CEL': 2174,
#   'VPH_INTER': 967,
#   'VPH_STVP': 1210,
#   'VPH_SPMVPI': 285,
#   'VPH_CVJ': 234},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 12,
#   'NOM_MUN': 'Ciénega de Flores',
#   'POBTOT': 68747,
#   'POBFEM': 33511,
#   'POBMAS': 35167,
#   'PEA': 33175,
#   'TVIVPARHAB': 20427,
#   'VPH_RADIO': 14145,
#   'VPH_TV': 18647,
#   'VPH_PC': 4973,
#   'VPH_TELEF': 5538,
#   'VPH_CEL': 19247,
#   'VPH_INTER': 10448,
#   'VPH_STVP': 7518,
#   'VPH_SPMVPI': 2549,
#   'VPH_CVJ': 1788},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 6,
#   'NOM_MUN': 'Apodaca',
#   'POBTOT': 656464,
#   'POBFEM': 324886,
#   'POBMAS': 331432,
#   'PEA': 338169,
#   'TVIVPARHAB': 181654,
#   'VPH_RADIO': 130402,
#   'VPH_TV': 176500,
#   'VPH_PC': 106046,
#   'VPH_TELEF': 114560,
#   'VPH_CEL': 174815,
#   'VPH_INTER': 147595,
#   'VPH_STVP': 85997,
#   'VPH_SPMVPI': 67476,
#   'VPH_CVJ': 45249},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 20,
#   'NOM_MUN': 'General Bravo',
#   'POBTOT': 5506,
#   'POBFEM': 2621,
#   'POBMAS': 2658,
#   'PEA': 2232,
#   'TVIVPARHAB': 1658,
#   'VPH_RADIO': 844,
#   'VPH_TV': 1570,
#   'VPH_PC': 420,
#   'VPH_TELEF': 543,
#   'VPH_CEL': 1523,
#   'VPH_INTER': 582,
#   'VPH_STVP': 696,
#   'VPH_SPMVPI': 152,
#   'VPH_CVJ': 101},
#  {'ENTIDAD': 19,
#   'NOM_ENT': 'Nuevo León',
#   'MUN': 14,
#   'NOM_MUN': 'Doctor Arroyo',
#   'POBTOT': 36088,
#   'POBFEM': 17895,
#   'POBMAS': 17912,
#   'PEA': 14944,
#   'TVIVPARHAB': 9142,
#   'VPH_RADIO': 5342,
#   'VPH_TV': 7835,
#   'VPH_PC': 1358,
#   'VPH_TELEF': 1572,
#   'VPH_CEL': 6870,
#   'VPH_INTER': 1473,
#   'VPH_STVP': 5258,
#   'VPH_SPMVPI': 323,
#   'VPH_CVJ': 216},
#  ...]

# %%
len(resultado_json)
# Out:
# 2469

# %%
# Setup connection to mongodb
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)
# Select database and collection to use
db = client.inclusion_digital
municipios = db.municipios
municipios.insert_many(resultado_json)
